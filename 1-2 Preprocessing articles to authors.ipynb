# %% [markdown]
# # 1. Using OpenAlex to find taxonomists
#
# ## 1.2. Preprocessing OpenAlex article data into author data
#
# Previously, we found a list of articles of taxonomic interest. Ultimately, we are interested in the authors, whom we assume are taxonomists or at least have relevant expertise about the taxon studied in the paper. We extract the information of the authors from the OpenAlex article data here.

# %%
import pandas as pd
import matplotlib.pyplot as plt # version 3.5.2
import pickle

# %% [markdown]
# ## Functions

# %%
# information locked in dictionaries inside the dataframe: open access, host (journal)

def get_dict_info(df_input): # input: articles straight from openalex
    hostcols = ['host_id', 'issn_l', 'issn', 'host_display_name', 'publisher',
                'host_type', 'host_url', 'is_host_oa', 'host_version', 'host_license']
    
    #df = pd.DataFrame(columns = hostcols + ["is_oa", "oa_status", "oa_url"])
    new_rows = []
    
    for article in df_input.itertuples():
        # get host (journal) info
        # if there is a list within the dictionary, pandas will turn it into two rows
        if article.host_venue["issn"] != None and len(article.host_venue["issn"]) != 1:
            article.host_venue["issn"] = '\n'.join(article.host_venue["issn"])
            
        l_journal = list(article.host_venue.values())
        l_oa = list(article.open_access.values())
        # unite open access and journal info from this article and previous articles
        l_new = l_journal + l_oa
        
        new_rows.append(l_new)
    
    # unite data in dictionaries with accessible data
    new_df = pd.DataFrame(new_rows, columns=hostcols + ["is_oa", "oa_status", "oa_url"])
    return df_input.merge(new_df, left_index=True, right_index=True)

# %%
# get authorship information from raw dataframe WITH all other data

def get_authors(df_input): # input: articles after get_dict_info
    # create empty dataframe with all authorship attributes
    df = pd.DataFrame()
    authors_list = []
    
    for article in df_input.itertuples():
        authors = pd.DataFrame(article.authorships)
        
        if len(authors) != 0:
            # disassemble author info
            for author in authors.itertuples():
                new_info = [article.id]+[author.author_position]+list(author.author.values())+[author.raw_affiliation_string]
                
                # add institution info
                if len(author.institutions) != 0:
                    new_info += list(author.institutions[0].values()) 
                else:
                    # no institution, no info
                    new_info += [None, None, None, None, None]
                authors_list.append(new_info) 
    
    new_df = pd.DataFrame(authors_list, 
                          columns=["article_id", "author_position", "author_id", "author_display_name", "orcid",
                                   "raw_affiliation_string", 
                                   "inst_id", "inst_display_name", "ror", "inst_country_code", "inst_type"])
    df = pd.concat([df, new_df])
    
    return pd.merge(df, df_input, left_on="article_id", right_on="id")

# %%
# keep most recent publication per author

def get_single_authors(df_input): # input: authors with doubles
    keep = []
    
    for author in set(df_input["author_id"]):
        # get all rows that match author
        publications = df_input[df_input["author_id"]==author]
        # get most recent one
        most_recent = publications["publication_date"].max()
        keep += publications[publications["publication_date"]==most_recent].values.tolist()
    
    keep_df = pd.DataFrame(keep,
                           columns = df_input.columns)
    
    # drop duplicates because some articles may have been found twice through different queries 
    # and some authors have published multiple relevant articles on the same day
    return keep_df.drop_duplicates(subset=["author_id"])

# %%
# filter a list of authors for authors who are asscociated with at least one European institution

def get_european_authors(df_input, pan_europe=False): # input: authors
    keep = []
    
    eu_codes = ["AT", "BE", "BG", "HR", "CY", "CZ", "DK", "EE", "FI", "FR", "DE", "GR", "HU", "IE", # EU
                  "IT", "LV", "LT", "LU", "MT", "NL", "PL", "PT", "RO", "SK", "SI", "ES", "SE"] # EU
    paneu_codes = ["IS", "LI", "NO", "CH", "AL", "ME", "MK", "RS", "TR", "AD", "BY", "BA", "MD", "MC", # pan-Europe
                   "RU", "SM", "UA", "GB", "VA", "GE", "AM", "AZ"] # pan-Europe
    
    for author in df_input.itertuples():
        # check every affiliated institute
        if author.inst_country_code in eu_codes:
            keep.append(author)
        elif pan_europe and author.inst_country_code in paneu_codes:
            keep.append(author)
    
    return pd.DataFrame(keep)

# %% [markdown]
# ## Results

# %%
eu_tax_articles = pd.read_pickle("./data/keyword_filtered_articles_EU27_with_taxonomy_concept_in_journal.pkl")
eu_tax_articles = get_dict_info(eu_tax_articles)
eu_tax_articles
# Out:
#                                      id  \
# 0      https://openalex.org/W2598914299
# 1      https://openalex.org/W2555892112
# 2      https://openalex.org/W2597855587
# 3      https://openalex.org/W2611147945
# 4      https://openalex.org/W2996133267
# ...                                 ...
# 12115  https://openalex.org/W3193573934
# 12116  https://openalex.org/W3202031023
# 12117  https://openalex.org/W4226104797
# 12118  https://openalex.org/W4302015794
# 12119  https://openalex.org/W4309431963
#
#                                               doi  \
# 0       https://doi.org/10.11646/bionomina.11.1.1
# 1       https://doi.org/10.11646/bionomina.10.1.1
# 2       https://doi.org/10.11646/bionomina.12.1.2
# 3       https://doi.org/10.11646/bionomina.12.1.8
# 4       https://doi.org/10.11646/bionomina.17.1.1
# ...                                           ...
# 12115  https://doi.org/10.31610/zsr/2021.30.2.169
# 12116  https://doi.org/10.31610/zsr/2021.30.2.190
# 12117   https://doi.org/10.31610/zsr/2022.31.1.27
# 12118  https://doi.org/10.31610/zsr/2022.31.2.182
# 12119  https://doi.org/10.31610/zsr/2022.31.2.195
#
#                                                    title  \
# 0      <p><strong>The nomenclatural status of <em>Hys...
# 1      &lt;p&gt;&lt;strong&gt;Classes, taxa and categ...
# 2      <strong>The need for reference specimens in zo...
# 3      &lt;strong&gt;Diagnoses in zoological taxonomy...
# 4      <p align="left"><strong>The Linz <em>Zoocode</...
# ...                                                  ...
# 12115  First record of the genus Colopterus (Coleopte...
# 12116  New species and new records of cuckoo wasps (H...
# 12117  A new species Chrysotus hubenovi and new data ...
# 12118  New records of Bibionidae (Diptera) from Azerb...
# 12119  Lepidochitona granpoderi sp. nov. (Mollusca: P...
#
#                                             display_name  publication_year  \
# 0      <p><strong>The nomenclatural status of <em>Hys...              2017
# 1      &lt;p&gt;&lt;strong&gt;Classes, taxa and categ...              2016
# 2      <strong>The need for reference specimens in zo...              2017
# 3      &lt;strong&gt;Diagnoses in zoological taxonomy...              2017
# 4      <p align="left"><strong>The Linz <em>Zoocode</...              2019
# ...                                                  ...               ...
# 12115  First record of the genus Colopterus (Coleopte...              2021
# 12116  New species and new records of cuckoo wasps (H...              2021
# 12117  A new species Chrysotus hubenovi and new data ...              2022
# 12118  New records of Bibionidae (Diptera) from Azerb...              2022
# 12119  Lepidochitona granpoderi sp. nov. (Mollusca: P...              2022
#
#       publication_date                                                ids  \
# 0           2017-03-04  {'openalex': 'https://openalex.org/W2598914299...
# 1           2016-11-10  {'openalex': 'https://openalex.org/W2555892112...
# 2           2017-03-24  {'openalex': 'https://openalex.org/W2597855587...
# 3           2017-03-24  {'openalex': 'https://openalex.org/W2611147945...
# 4           2019-12-17  {'openalex': 'https://openalex.org/W2996133267...
# ...                ...                                                ...
# 12115       2021-08-14  {'openalex': 'https://openalex.org/W3193573934...
# 12116       2021-10-05  {'openalex': 'https://openalex.org/W3202031023...
# 12117       2022-04-04  {'openalex': 'https://openalex.org/W4226104797...
# 12118       2022-10-04  {'openalex': 'https://openalex.org/W4302015794...
# 12119       2022-11-20  {'openalex': 'https://openalex.org/W4309431963...
#
#                                         primary_location  \
# 0      {'is_oa': None, 'landing_page_url': 'https://d...
# 1      {'is_oa': True, 'landing_page_url': 'https://d...
# 2      {'is_oa': None, 'landing_page_url': 'https://d...
# 3      {'is_oa': None, 'landing_page_url': 'https://d...
# 4      {'is_oa': True, 'landing_page_url': 'https://d...
# ...                                                  ...
# 12115  {'is_oa': None, 'landing_page_url': 'https://d...
# 12116  {'is_oa': None, 'landing_page_url': 'https://d...
# 12117  {'is_oa': None, 'landing_page_url': 'https://d...
# 12118  {'is_oa': None, 'landing_page_url': 'https://d...
# 12119  {'is_oa': None, 'landing_page_url': 'https://d...
#
#                                               host_venue             type  \
# 0      {'id': 'https://openalex.org/S4210230724', 'is...  journal-article
# 1      {'id': 'https://openalex.org/S4210230724', 'is...  journal-article
# 2      {'id': 'https://openalex.org/S4210230724', 'is...  journal-article
# 3      {'id': 'https://openalex.org/S4210230724', 'is...  journal-article
# 4      {'id': 'https://openalex.org/S4210230724', 'is...  journal-article
# ...                                                  ...              ...
# 12115  {'id': 'https://openalex.org/S2764648274', 'is...  journal-article
# 12116  {'id': 'https://openalex.org/S2764648274', 'is...  journal-article
# 12117  {'id': 'https://openalex.org/S2764648274', 'is...  journal-article
# 12118  {'id': 'https://openalex.org/S2764648274', 'is...  journal-article
# 12119  {'id': 'https://openalex.org/S2764648274', 'is...  journal-article
#
#        ...       host_display_name  \
# 0      ...               Bionomina
# 1      ...               Bionomina
# 2      ...               Bionomina
# 3      ...               Bionomina
# 4      ...               Bionomina
# ...    ...                     ...
# 12115  ...  Zoosystematica Rossica
# 12116  ...  Zoosystematica Rossica
# 12117  ...  Zoosystematica Rossica
# 12118  ...  Zoosystematica Rossica
# 12119  ...  Zoosystematica Rossica
#
#                                                publisher  host_type  \
# 0                                              Q15088586    journal
# 1                                              Q15088586    journal
# 2                                              Q15088586    journal
# 3                                              Q15088586    journal
# 4                                              Q15088586    journal
# ...                                                  ...        ...
# 12115  Zoological Institute of the Russian Academy of...    journal
# 12116  Zoological Institute of the Russian Academy of...    journal
# 12117  Zoological Institute of the Russian Academy of...    journal
# 12118  Zoological Institute of the Russian Academy of...    journal
# 12119  Zoological Institute of the Russian Academy of...    journal
#
#                                                 host_url  is_host_oa  \
# 0                                                   None       False
# 1      https://www.mapress.com/j/bn/article/download/...        True
# 2                                                   None       False
# 3                                                   None       False
# 4      https://www.mapress.com/bn/article/download/bi...        True
# ...                                                  ...         ...
# 12115                                               None       False
# 12116                                               None       False
# 12117                                               None       False
# 12118                                               None       False
# 12119                                               None       False
#
#            host_version host_license  is_oa oa_status  \
# 0                  None         None  False    closed
# 1      publishedVersion         None   True    bronze
# 2                  None         None  False    closed
# 3                  None         None  False    closed
# 4      publishedVersion         None   True    bronze
# ...                 ...          ...    ...       ...
# 12115              None         None  False    closed
# 12116              None         None  False    closed
# 12117              None         None  False    closed
# 12118              None         None  False    closed
# 12119              None         None  False    closed
#
#                                                   oa_url
# 0                                                   None
# 1      https://www.mapress.com/j/bn/article/download/...
# 2                                                   None
# 3                                                   None
# 4      https://www.mapress.com/bn/article/download/bi...
# ...                                                  ...
# 12115                                               None
# 12116                                               None
# 12117                                               None
# 12118                                               None
# 12119                                               None
#
# [12120 rows x 43 columns]

# %%
authors_eu_tax = get_authors(eu_tax_articles)
authors_eu_tax
# Out:
#                              article_id author_position  \
# 0      https://openalex.org/W2598914299           first
# 1      https://openalex.org/W2555892112           first
# 2      https://openalex.org/W2597855587           first
# 3      https://openalex.org/W2611147945           first
# 4      https://openalex.org/W2996133267           first
# ...                                 ...             ...
# 52648  https://openalex.org/W4302015794          middle
# 52649  https://openalex.org/W4302015794            last
# 52650  https://openalex.org/W4309431963           first
# 52651  https://openalex.org/W4309431963          middle
# 52652  https://openalex.org/W4309431963            last
#
#                               author_id        author_display_name  \
# 0      https://openalex.org/A2596859121               Alain Dubois
# 1       https://openalex.org/A164956482  Marc H.V. Van Regenmortel
# 2      https://openalex.org/A2596859121               Alain Dubois
# 3      https://openalex.org/A2596859121               Alain Dubois
# 4      https://openalex.org/A2596859121               Alain Dubois
# ...                                 ...                        ...
# 52648  https://openalex.org/A4302125241               Manko, Peter
# 52649  https://openalex.org/A4302125242              Oboňa,  Jozef
# 52650  https://openalex.org/A4309432000         Dell'Angelo, Bruno
# 52651  https://openalex.org/A4309432001          Sirenko, Boris I.
# 52652  https://openalex.org/A4309432002             Anseeuw, Bruno
#
#                                        orcid  \
# 0      https://orcid.org/0000-0002-6463-3435
# 1      https://orcid.org/0000-0002-8200-8465
# 2      https://orcid.org/0000-0002-6463-3435
# 3      https://orcid.org/0000-0002-6463-3435
# 4      https://orcid.org/0000-0002-6463-3435
# ...                                      ...
# 52648                                   None
# 52649                                   None
# 52650                                   None
# 52651                                   None
# 52652                                   None
#
#                                   raw_affiliation_string  \
# 0      Institut de Systématique, Évolution, Biodivers...
# 1      UMR 7242 Biotechnologie et Signalisation Cellu...
# 2      Institut de Systématique, Évolution, Biodivers...
# 3      Institut de Systématique, Évolution, Biodivers...
# 4      Institut De Systématique, Évolution, Biodivers...
# ...                                                  ...
# 52648  Department of Ecology, Faculty of Humanities a...
# 52649  Department of Ecology, Faculty of Humanities a...
# 52650              Via Briscata 16, 16154, Genova, Italy
# 52651  Zoological Institute, Russian Academy of Scien...
# 52652  Malacology Section, Royal Belgian Institute of...
#
#                                 inst_id  \
# 0      https://openalex.org/I4210103322
# 1      https://openalex.org/I4210145673
# 2      https://openalex.org/I4210103322
# 3      https://openalex.org/I4210103322
# 4      https://openalex.org/I4210103322
# ...                                 ...
# 52648   https://openalex.org/I173161963
# 52649   https://openalex.org/I173161963
# 52650                              None
# 52651  https://openalex.org/I2801680271
# 52652  https://openalex.org/I2801223450
#
#                                        inst_display_name  \
# 0      Institut de Systématique, Évolution, Biodiversité
# 1             Biotechnologie et Signalisation Cellulaire
# 2      Institut de Systématique, Évolution, Biodiversité
# 3      Institut de Systématique, Évolution, Biodiversité
# 4      Institut de Systématique, Évolution, Biodiversité
# ...                                                  ...
# 52648                               University of Prešov
# 52649                               University of Prešov
# 52650              Via Briscata 16, 16154, Genova, Italy
# 52651                               Zoological Institute
# 52652        Royal Belgian Institute of Natural Sciences
#
#                              ror inst_country_code  ...  \
# 0      https://ror.org/01dadvw90                FR  ...
# 1      https://ror.org/047fwb937                FR  ...
# 2      https://ror.org/01dadvw90                FR  ...
# 3      https://ror.org/01dadvw90                FR  ...
# 4      https://ror.org/01dadvw90                FR  ...
# ...                          ...               ...  ...
# 52648  https://ror.org/02ndfsn03                SK  ...
# 52649  https://ror.org/02ndfsn03                SK  ...
# 52650                       None              None  ...
# 52651  https://ror.org/05snbjh64                RU  ...
# 52652  https://ror.org/02y22ws83                BE  ...
#
#             host_display_name  \
# 0                   Bionomina
# 1                   Bionomina
# 2                   Bionomina
# 3                   Bionomina
# 4                   Bionomina
# ...                       ...
# 52648  Zoosystematica Rossica
# 52649  Zoosystematica Rossica
# 52650  Zoosystematica Rossica
# 52651  Zoosystematica Rossica
# 52652  Zoosystematica Rossica
#
#                                                publisher host_type  \
# 0                                              Q15088586   journal
# 1                                              Q15088586   journal
# 2                                              Q15088586   journal
# 3                                              Q15088586   journal
# 4                                              Q15088586   journal
# ...                                                  ...       ...
# 52648  Zoological Institute of the Russian Academy of...   journal
# 52649  Zoological Institute of the Russian Academy of...   journal
# 52650  Zoological Institute of the Russian Academy of...   journal
# 52651  Zoological Institute of the Russian Academy of...   journal
# 52652  Zoological Institute of the Russian Academy of...   journal
#
#                                                 host_url is_host_oa  \
# 0                                                   None      False
# 1      https://www.mapress.com/j/bn/article/download/...       True
# 2                                                   None      False
# 3                                                   None      False
# 4      https://www.mapress.com/bn/article/download/bi...       True
# ...                                                  ...        ...
# 52648                                               None      False
# 52649                                               None      False
# 52650                                               None      False
# 52651                                               None      False
# 52652                                               None      False
#
#            host_version host_license  is_oa oa_status  \
# 0                  None         None  False    closed
# 1      publishedVersion         None   True    bronze
# 2                  None         None  False    closed
# 3                  None         None  False    closed
# 4      publishedVersion         None   True    bronze
# ...                 ...          ...    ...       ...
# 52648              None         None  False    closed
# 52649              None         None  False    closed
# 52650              None         None  False    closed
# 52651              None         None  False    closed
# 52652              None         None  False    closed
#
#                                                   oa_url
# 0                                                   None
# 1      https://www.mapress.com/j/bn/article/download/...
# 2                                                   None
# 3                                                   None
# 4      https://www.mapress.com/bn/article/download/bi...
# ...                                                  ...
# 52648                                               None
# 52649                                               None
# 52650                                               None
# 52651                                               None
# 52652                                               None
#
# [52653 rows x 54 columns]

# %%
only_eu_authors = get_european_authors(authors_eu_tax)
only_eu_authors
# Out:
#        Index                        article_id author_position  \
# 0          0  https://openalex.org/W2598914299           first
# 1          1  https://openalex.org/W2555892112           first
# 2          2  https://openalex.org/W2597855587           first
# 3          3  https://openalex.org/W2611147945           first
# 4          4  https://openalex.org/W2996133267           first
# ...      ...                               ...             ...
# 26075  52643  https://openalex.org/W4226104797           first
# 26076  52646  https://openalex.org/W4302015794           first
# 26077  52648  https://openalex.org/W4302015794          middle
# 26078  52649  https://openalex.org/W4302015794            last
# 26079  52652  https://openalex.org/W4309431963            last
#
#                               author_id        author_display_name  \
# 0      https://openalex.org/A2596859121               Alain Dubois
# 1       https://openalex.org/A164956482  Marc H.V. Van Regenmortel
# 2      https://openalex.org/A2596859121               Alain Dubois
# 3      https://openalex.org/A2596859121               Alain Dubois
# 4      https://openalex.org/A2596859121               Alain Dubois
# ...                                 ...                        ...
# 26075  https://openalex.org/A2680309858              Mihail Kechev
# 26076  https://openalex.org/A4302125239              Dvořák, Libor
# 26077  https://openalex.org/A4302125241               Manko, Peter
# 26078  https://openalex.org/A4302125242              Oboňa,  Jozef
# 26079  https://openalex.org/A4309432002             Anseeuw, Bruno
#
#                                        orcid  \
# 0      https://orcid.org/0000-0002-6463-3435
# 1      https://orcid.org/0000-0002-8200-8465
# 2      https://orcid.org/0000-0002-6463-3435
# 3      https://orcid.org/0000-0002-6463-3435
# 4      https://orcid.org/0000-0002-6463-3435
# ...                                      ...
# 26075                                   None
# 26076                                   None
# 26077                                   None
# 26078                                   None
# 26079                                   None
#
#                                   raw_affiliation_string  \
# 0      Institut de Systématique, Évolution, Biodivers...
# 1      UMR 7242 Biotechnologie et Signalisation Cellu...
# 2      Institut de Systématique, Évolution, Biodivers...
# 3      Institut de Systématique, Évolution, Biodivers...
# 4      Institut De Systématique, Évolution, Biodivers...
# ...                                                  ...
# 26075  Forest Research Institute, Bulgarian Academy o...
# 26076  Tři Sekery 21, CZ – 353 01 Mariánské Lázně, Cz...
# 26077  Department of Ecology, Faculty of Humanities a...
# 26078  Department of Ecology, Faculty of Humanities a...
# 26079  Malacology Section, Royal Belgian Institute of...
#
#                                 inst_id  \
# 0      https://openalex.org/I4210103322
# 1      https://openalex.org/I4210145673
# 2      https://openalex.org/I4210103322
# 3      https://openalex.org/I4210103322
# 4      https://openalex.org/I4210103322
# ...                                 ...
# 26075    https://openalex.org/I24768866
# 26076  https://openalex.org/I4210137292
# 26077   https://openalex.org/I173161963
# 26078   https://openalex.org/I173161963
# 26079  https://openalex.org/I2801223450
#
#                                        inst_display_name  \
# 0      Institut de Systématique, Évolution, Biodiversité
# 1             Biotechnologie et Signalisation Cellulaire
# 2      Institut de Systématique, Évolution, Biodiversité
# 3      Institut de Systématique, Évolution, Biodiversité
# 4      Institut de Systématique, Évolution, Biodiversité
# ...                                                  ...
# 26075                      Bulgarian Academy of Sciences
# 26076                                 Třinecké Železárny
# 26077                               University of Prešov
# 26078                               University of Prešov
# 26079        Royal Belgian Institute of Natural Sciences
#
#                              ror  ...       host_display_name  \
# 0      https://ror.org/01dadvw90  ...               Bionomina
# 1      https://ror.org/047fwb937  ...               Bionomina
# 2      https://ror.org/01dadvw90  ...               Bionomina
# 3      https://ror.org/01dadvw90  ...               Bionomina
# 4      https://ror.org/01dadvw90  ...               Bionomina
# ...                          ...  ...                     ...
# 26075  https://ror.org/01x8hew03  ...  Zoosystematica Rossica
# 26076  https://ror.org/041c53527  ...  Zoosystematica Rossica
# 26077  https://ror.org/02ndfsn03  ...  Zoosystematica Rossica
# 26078  https://ror.org/02ndfsn03  ...  Zoosystematica Rossica
# 26079  https://ror.org/02y22ws83  ...  Zoosystematica Rossica
#
#                                                publisher host_type  \
# 0                                              Q15088586   journal
# 1                                              Q15088586   journal
# 2                                              Q15088586   journal
# 3                                              Q15088586   journal
# 4                                              Q15088586   journal
# ...                                                  ...       ...
# 26075  Zoological Institute of the Russian Academy of...   journal
# 26076  Zoological Institute of the Russian Academy of...   journal
# 26077  Zoological Institute of the Russian Academy of...   journal
# 26078  Zoological Institute of the Russian Academy of...   journal
# 26079  Zoological Institute of the Russian Academy of...   journal
#
#                                                 host_url is_host_oa  \
# 0                                                   None      False
# 1      https://www.mapress.com/j/bn/article/download/...       True
# 2                                                   None      False
# 3                                                   None      False
# 4      https://www.mapress.com/bn/article/download/bi...       True
# ...                                                  ...        ...
# 26075                                               None      False
# 26076                                               None      False
# 26077                                               None      False
# 26078                                               None      False
# 26079                                               None      False
#
#            host_version  host_license  is_oa oa_status  \
# 0                  None          None  False    closed
# 1      publishedVersion          None   True    bronze
# 2                  None          None  False    closed
# 3                  None          None  False    closed
# 4      publishedVersion          None   True    bronze
# ...                 ...           ...    ...       ...
# 26075              None          None  False    closed
# 26076              None          None  False    closed
# 26077              None          None  False    closed
# 26078              None          None  False    closed
# 26079              None          None  False    closed
#
#                                                   oa_url
# 0                                                   None
# 1      https://www.mapress.com/j/bn/article/download/...
# 2                                                   None
# 3                                                   None
# 4      https://www.mapress.com/bn/article/download/bi...
# ...                                                  ...
# 26075                                               None
# 26076                                               None
# 26077                                               None
# 26078                                               None
# 26079                                               None
#
# [26080 rows x 55 columns]

# %%
single_eu_authors = get_single_authors(only_eu_authors).reset_index(drop=True)
single_eu_authors
# Out:
#       Index                        article_id author_position  \
# 0     45521  https://openalex.org/W1198660990          middle
# 1     14863  https://openalex.org/W3135121471            last
# 2     52330  https://openalex.org/W4200400740          middle
# 3     40361  https://openalex.org/W2916627082           first
# 4     44992  https://openalex.org/W2592793920          middle
# ...     ...                               ...             ...
# 9602  12745  https://openalex.org/W2074722678          middle
# 9603  34351  https://openalex.org/W3195655516            last
# 9604  23180  https://openalex.org/W2789590705          middle
# 9605  16791  https://openalex.org/W2185382798          middle
# 9606  32166  https://openalex.org/W4210749143           first
#
#                              author_id      author_display_name  \
# 0     https://openalex.org/A1972576541           Bernard Laurin
# 1     https://openalex.org/A2223790226        Roberto Venanzoni
# 2     https://openalex.org/A1690698565        Benoit Gouillieux
# 3     https://openalex.org/A1960157388           Filippo Milano
# 4     https://openalex.org/A2756326157  Arlete Ramos dos Santos
# ...                                ...                      ...
# 9602  https://openalex.org/A2279582608         Giovanni Perrone
# 9603  https://openalex.org/A2555322479        Bernard R. Landau
# 9604  https://openalex.org/A2052733317           Urban Tillmann
# 9605  https://openalex.org/A2147050111        Agustín Caballero
# 9606  https://openalex.org/A2199296871             Oscar Puebla
#
#                                       orcid  \
# 0                                      None
# 1     https://orcid.org/0000-0002-7768-0468
# 2     https://orcid.org/0000-0002-5412-8582
# 3     https://orcid.org/0000-0003-3573-2159
# 4     https://orcid.org/0000-0003-0217-3805
# ...                                     ...
# 9602  https://orcid.org/0000-0002-9336-8810
# 9603                                   None
# 9604  https://orcid.org/0000-0002-8207-4382
# 9605                                   None
# 9606  https://orcid.org/0000-0001-9700-5841
#
#                                  raw_affiliation_string  \
# 0     Biogéosciences, UMR CNRS 6282, Université de B...
# 1     Department of Chemistry, Biology and Biotechno...
# 2     CNRS, Univ. Bordeaux, EPOC, UMR 5805, Station ...
# 3     Lab. di Ecologia – Ecosistemi terrestri, Dipar...
# 4     i3S - Instituto de Investigação e Inovação em ...
# ...                                                 ...
# 9602  Institute of Sciences of Food Production Natio...
# 9603
# 9604  Alfred-Wegener-Institut – Helmholtz-Zentrum fü...
# 9605  C/ Andalucía 3, 4.º dcha. 26500 Calahorra, La ...
# 9606  Leibniz-Centre for Tropical Marine Research (Z...
#
#                                inst_id  \
# 0     https://openalex.org/I4210158426
# 1       https://openalex.org/I27483092
# 2     https://openalex.org/I1294671590
# 3       https://openalex.org/I55143463
# 4     https://openalex.org/I4210158732
# ...                                ...
# 9602  https://openalex.org/I4210131270
# 9603  https://openalex.org/I1295562517
# 9604   https://openalex.org/I127251866
# 9605   https://openalex.org/I918821925
# 9606  https://openalex.org/I2799883060
#
#                                       inst_display_name  \
# 0                                        Biogéosciences
# 1                                 University of Perugia
# 2        French National Centre for Scientific Research
# 3                                   University of Turin
# 4        i3S - Health Research and Innovation Institute
# ...                                                 ...
# 9602           Institute of Sciences of Food Production
# 9603                      Naturalis Biodiversity Center
# 9604  Alfred Wegener Institute for Polar and Marine ...
# 9605                   Regional Government of Andalusia
# 9606        Leibniz Centre for Tropical Marine Research
#
#                             ror  ...                      host_display_name  \
# 0     https://ror.org/04mzqjs78  ...  Molecular Phylogenetics and Evolution
# 1     https://ror.org/00x27da85  ...                              Phytotaxa
# 2     https://ror.org/02feahw73  ...           European journal of taxonomy
# 3     https://ror.org/048tbm396  ...                             Zoosystema
# 4     https://ror.org/04wjk1035  ...  Molecular Phylogenetics and Evolution
# ...                         ...  ...                                    ...
# 9602  https://ror.org/03x7xkr71  ...                    Studies in Mycology
# 9603  https://ror.org/0566bfb96  ...                                Zootaxa
# 9604  https://ror.org/032e6b942  ...                                  Taxon
# 9605  https://ror.org/01jem9c82  ...                              Phytotaxa
# 9606  https://ror.org/019w00969  ...                                Zootaxa
#
#                                            publisher host_type  \
# 0                                        Elsevier BV   journal
# 1                                          Q15088586   journal
# 2     Consortium of European Natural History Museums   journal
# 3               Muséum national d'histoire naturelle   journal
# 4                                        Elsevier BV   journal
# ...                                              ...       ...
# 9602                                     Elsevier BV   journal
# 9603                                       Q15088586   journal
# 9604                                           Wiley   journal
# 9605                                       Q15088586   journal
# 9606                                       Q15088586   journal
#
#                                                host_url is_host_oa  \
# 0                                                  None      False
# 1                                                  None      False
# 2     https://europeanjournaloftaxonomy.eu/index.php...       True
# 3                                                  None      False
# 4                                                  None      False
# ...                                                 ...        ...
# 9602       https://doi.org/10.1016/j.simyco.2014.07.004       True
# 9603                                               None      False
# 9604                                               None      False
# 9605                                               None      False
# 9606                                               None      False
#
#           host_version  host_license  is_oa oa_status  \
# 0                 None          None   True     green
# 1                 None          None  False    closed
# 2     publishedVersion         cc-by   True      gold
# 3                 None          None   True     green
# 4                 None          None  False    closed
# ...                ...           ...    ...       ...
# 9602  publishedVersion   cc-by-nc-nd   True      gold
# 9603              None          None  False    closed
# 9604              None          None   True     green
# 9605              None          None  False    closed
# 9606              None          None  False    closed
#
#                                                  oa_url
# 0     https://hal.archives-ouvertes.fr/hal-01205849/...
# 1                                                  None
# 2     https://europeanjournaloftaxonomy.eu/index.php...
# 3     https://hal-mnhn.archives-ouvertes.fr/mnhn-027...
# 4                                                  None
# ...                                                 ...
# 9602       https://doi.org/10.1016/j.simyco.2014.07.004
# 9603                                               None
# 9604  https://epic.awi.de/id/eprint/46918/1/2018_Got...
# 9605                                               None
# 9606                                               None
#
# [9607 rows x 55 columns]

# %%
only_eu_authors.to_pickle("./data/EU27_authors_with_all_taxonomic_articles.pkl")
single_eu_authors.to_pickle("./data/EU27_authors_taxonomic_articles_no_duplicates.pkl")

# %% [markdown]
# We now have a list of all European authors of taxonomic articles from taxonomic journals.

# %% [markdown]
# ## Insects (RLIT methodology)

# %%
insect_articles = pd.read_pickle("./data/RLIT_method_openalex_all_insect_articles.pkl")
insect_articles = get_dict_info(insect_articles)
insect_articles
# Out:
#                                      id  \
# 0      https://openalex.org/W2075105050
# 0      https://openalex.org/W1971821649
# 0      https://openalex.org/W2188404336
# 0      https://openalex.org/W2039380629
# 0      https://openalex.org/W2092029632
# ...                                 ...
# 11701  https://openalex.org/W2915290188
# 11702  https://openalex.org/W2185029227
# 11703  https://openalex.org/W2155430078
# 11704  https://openalex.org/W2923711627
# 11705  https://openalex.org/W2785376982
#
#                                                 doi  \
# 0          https://doi.org/10.3897/zookeys.186.2947
# 0           https://doi.org/10.1590/0074-0276130434
# 0         https://doi.org/10.11646/zootaxa.2740.1.1
# 0      https://doi.org/10.1371/journal.pone.0122407
# 0         https://doi.org/10.1007/s13127-012-0123-1
# ...                                             ...
# 11701     https://doi.org/10.1134/s0013873818080134
# 11702                                          None
# 11703       https://doi.org/10.4038/tapro.v4i2.5058
# 11704          https://doi.org/10.33800/nc.v0i5.141
# 11705      https://doi.org/10.21068/c2017.v18n02a19
#
#                                                    title  \
# 0      New species and distributional records of Aleo...
# 0      Rhodnius barretti, a new species of Triatomina...
# 0      New species of and taxonomic notes on Anastrep...
# 0      Phylogenetic Molecular Species Delimitations U...
# 0      Biogeography, ecology, acoustics and chromosom...
# ...                                                  ...
# 11701  A Review of the Leaf-Beetle Fauna (Coleoptera,...
# 11702  A preliminary study on the species diversity o...
# 11703  Bolboceratine scarabs of genera Bolbohamatum K...
# 11704  Corrigenda a los escarabajos (Coleoptera) en l...
# 11705  Carábidos (Coleoptera: Carabidae) del Museo de...
#
#                                             display_name  relevance_score  \
# 0      New species and distributional records of Aleo...       186.240310
# 0      Rhodnius barretti, a new species of Triatomina...       281.430050
# 0      New species of and taxonomic notes on Anastrep...       231.417570
# 0      Phylogenetic Molecular Species Delimitations U...       237.500000
# 0      Biogeography, ecology, acoustics and chromosom...       174.616700
# ...                                                  ...              ...
# 11701  A Review of the Leaf-Beetle Fauna (Coleoptera,...        41.702457
# 11702  A preliminary study on the species diversity o...        33.008816
# 11703  Bolboceratine scarabs of genera Bolbohamatum K...        20.918540
# 11704  Corrigenda a los escarabajos (Coleoptera) en l...              NaN
# 11705  Carábidos (Coleoptera: Carabidae) del Museo de...              NaN
#
#        publication_year publication_date  \
# 0                  2012       2012-04-26
# 0                  2013       2013-01-01
# 0                  2011       2011-01-14
# 0                  2015       2015-04-08
# 0                  2013       2013-02-09
# ...                 ...              ...
# 11701              2018       2018-11-01
# 11702              2012       2012-01-01
# 11703              2012       2012-12-25
# 11704              2012       2012-07-01
# 11705              2018       2018-03-13
#
#                                                      ids  \
# 0      {'openalex': 'https://openalex.org/W2075105050...
# 0      {'openalex': 'https://openalex.org/W1971821649...
# 0      {'openalex': 'https://openalex.org/W2188404336...
# 0      {'openalex': 'https://openalex.org/W2039380629...
# 0      {'openalex': 'https://openalex.org/W2092029632...
# ...                                                  ...
# 11701  {'openalex': 'https://openalex.org/W2915290188...
# 11702  {'openalex': 'https://openalex.org/W2185029227...
# 11703  {'openalex': 'https://openalex.org/W2155430078...
# 11704  {'openalex': 'https://openalex.org/W2923711627...
# 11705  {'openalex': 'https://openalex.org/W2785376982...
#
#                                         primary_location  \
# 0      {'is_oa': True, 'landing_page_url': 'https://d...
# 0      {'is_oa': True, 'landing_page_url': 'https://d...
# 0      {'is_oa': True, 'landing_page_url': 'https://d...
# 0      {'is_oa': True, 'landing_page_url': 'https://d...
# 0      {'is_oa': None, 'landing_page_url': 'https://d...
# ...                                                  ...
# 11701  {'is_oa': None, 'landing_page_url': 'https://d...
# 11702  {'is_oa': None, 'landing_page_url': None, 'pdf...
# 11703  {'is_oa': True, 'landing_page_url': 'https://d...
# 11704  {'is_oa': True, 'landing_page_url': 'https://d...
# 11705  {'is_oa': True, 'landing_page_url': 'https://d...
#
#                                               host_venue  ...  \
# 0      {'id': 'https://openalex.org/S199213172', 'iss...  ...
# 0      {'id': 'https://openalex.org/S165991124', 'iss...  ...
# 0      {'id': 'https://openalex.org/S171471881', 'iss...  ...
# 0      {'id': 'https://openalex.org/S202381698', 'iss...  ...
# 0      {'id': 'https://openalex.org/S190011727', 'iss...  ...
# ...                                                  ...  ...
# 11701  {'id': 'https://openalex.org/S17264655', 'issn...  ...
# 11702  {'id': None, 'issn_l': None, 'issn': None, 'di...  ...
# 11703  {'id': 'https://openalex.org/S2764827249', 'is...  ...
# 11704  {'id': 'https://openalex.org/S4210185428', 'is...  ...
# 11705  {'id': 'https://openalex.org/S4210212155', 'is...  ...
#
#                                     host_display_name  \
# 0                                             ZooKeys
# 0                                             ZooKeys
# 0                                             ZooKeys
# 0                                             ZooKeys
# 0                                             ZooKeys
# ...                                               ...
# 11701                            Entomological Review
# 11702                                            None
# 11703  TAPROBANICA: The Journal of Asian Biodiversity
# 11704                              Novitates Caribaea
# 11705                                Biota Colombiana
#
#                                                publisher host_type  \
# 0                                     Pensoft Publishers   journal
# 0                                     Pensoft Publishers   journal
# 0                                     Pensoft Publishers   journal
# 0                                     Pensoft Publishers   journal
# 0                                     Pensoft Publishers   journal
# ...                                                  ...       ...
# 11701                                Pleiades Publishing   journal
# 11702                                               None      None
# 11703  Research Center for Climate Change, University...   journal
# 11704  Museo Nacional de Historia Natural, Prof. Euge...   journal
# 11705  Alexander von Humboldt Biological Resources Re...   journal
#
#                                                 host_url is_host_oa  \
# 0      https://zookeys.pensoft.net/article/2702/downl...       True
# 0      https://zookeys.pensoft.net/article/2702/downl...       True
# 0      https://zookeys.pensoft.net/article/2702/downl...       True
# 0      https://zookeys.pensoft.net/article/2702/downl...       True
# 0      https://zookeys.pensoft.net/article/2702/downl...       True
# ...                                                  ...        ...
# 11701                                               None      False
# 11702                                               None      False
# 11703  http://tapro.sljol.info/articles/10.4038/tapro...       True
# 11704  http://novitatescaribaea.do/index.php/novitate...       True
# 11705           https://doi.org/10.21068/c2017.v18n02a19       True
#
#            host_version host_license  is_oa oa_status  \
# 0      publishedVersion        cc-by   True      gold
# 0      publishedVersion        cc-by   True      gold
# 0      publishedVersion        cc-by   True      gold
# 0      publishedVersion        cc-by   True      gold
# 0      publishedVersion        cc-by   True      gold
# ...                 ...          ...    ...       ...
# 11701              None         None  False    closed
# 11702              None         None  False      None
# 11703  publishedVersion        cc-by   True    hybrid
# 11704  publishedVersion     cc-by-nc   True      gold
# 11705  publishedVersion  cc-by-nc-nd   True      gold
#
#                                                   oa_url
# 0      https://zookeys.pensoft.net/article/2702/downl...
# 0      https://zookeys.pensoft.net/article/2702/downl...
# 0      https://zookeys.pensoft.net/article/2702/downl...
# 0      https://zookeys.pensoft.net/article/2702/downl...
# 0      https://zookeys.pensoft.net/article/2702/downl...
# ...                                                  ...
# 11701                                               None
# 11702                                               None
# 11703  http://tapro.sljol.info/articles/10.4038/tapro...
# 11704  http://novitatescaribaea.do/index.php/novitate...
# 11705           https://doi.org/10.21068/c2017.v18n02a19
#
# [45598 rows x 45 columns]

# %%
authors_insects = get_authors(insect_articles)
authors_insects
# Out:
#                               article_id author_position  \
# 0       https://openalex.org/W2075105050           first
# 1       https://openalex.org/W2075105050          middle
# 2       https://openalex.org/W2075105050          middle
# 3       https://openalex.org/W2075105050          middle
# 4       https://openalex.org/W2075105050          middle
# ...                                  ...             ...
# 199667  https://openalex.org/W2155430078           first
# 199668  https://openalex.org/W2155430078            last
# 199669  https://openalex.org/W2923711627           first
# 199670  https://openalex.org/W2785376982           first
# 199671  https://openalex.org/W2785376982            last
#
#                                author_id       author_display_name  \
# 0       https://openalex.org/A2634481662               Adam Brunke
# 1       https://openalex.org/A1954442483          Jan Klimaszewski
# 2       https://openalex.org/A2592732627         Julie-Anne Dorval
# 3       https://openalex.org/A2021629399          Caroline Bourdon
# 4       https://openalex.org/A1430890116              S. M. Paiero
# ...                                  ...                       ...
# 199667  https://openalex.org/A2112005922           Kailash Chandra
# 199668  https://openalex.org/A2128748613            Devanshu Gupta
# 199669  https://openalex.org/A2798555197  Daniel E. Perez-Gelabert
# 199670  https://openalex.org/A2531322189   Anderson Arenas-Clavijo
# 199671   https://openalex.org/A337147391  Carmen Elisa Posso-Gómez
#
#                                         orcid  \
# 0       https://orcid.org/0000-0003-1158-936X
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 199667  https://orcid.org/0000-0001-9076-5442
# 199668  https://orcid.org/0000-0001-9188-4689
# 199669                                   None
# 199670  https://orcid.org/0000-0001-5639-5273
# 199671                                   None
#
#                                    raw_affiliation_string  \
# 0       Zoological Museum (Natural History Museum of D...
# 1
# 2
# 3
# 4
# ...                                                   ...
# 199667  Zoological Survey of India, New Alipore, Kolka...
# 199668  Zoological Survey of India, Jabalpur 482002, M...
# 199669  United States National Museum of Natural Histo...
# 199670  Sección de Entomología,#R##N#Departamento de B...
# 199671  Sección de Entomología,#R##N#Departamento de B...
#
#                                  inst_id                   inst_display_name  \
# 0       https://openalex.org/I4210110903              Natural History Museum
# 1                                   None                                None
# 2                                   None                                None
# 3                                   None                                None
# 4                                   None                                None
# ...                                  ...                                 ...
# 199667  https://openalex.org/I1338006420          Zoological Survey of India
# 199668  https://openalex.org/I1338006420          Zoological Survey of India
# 199669  https://openalex.org/I1341618623  National Museum of Natural History
# 199670    https://openalex.org/I91732220                 University of Valle
# 199671    https://openalex.org/I91732220                 University of Valle
#
#                               ror inst_country_code  ...  \
# 0       https://ror.org/0166x0j30                DK  ...
# 1                            None              None  ...
# 2                            None              None  ...
# 3                            None              None  ...
# 4                            None              None  ...
# ...                           ...               ...  ...
# 199667  https://ror.org/00h6p6a20                IN  ...
# 199668  https://ror.org/00h6p6a20                IN  ...
# 199669  https://ror.org/00cz47042                US  ...
# 199670  https://ror.org/00jb9vg53                CO  ...
# 199671  https://ror.org/00jb9vg53                CO  ...
#
#                                      host_display_name  \
# 0                                              ZooKeys
# 1                                              ZooKeys
# 2                                              ZooKeys
# 3                                              ZooKeys
# 4                                              ZooKeys
# ...                                                ...
# 199667  TAPROBANICA: The Journal of Asian Biodiversity
# 199668  TAPROBANICA: The Journal of Asian Biodiversity
# 199669                              Novitates Caribaea
# 199670                                Biota Colombiana
# 199671                                Biota Colombiana
#
#                                                 publisher host_type  \
# 0                                      Pensoft Publishers   journal
# 1                                      Pensoft Publishers   journal
# 2                                      Pensoft Publishers   journal
# 3                                      Pensoft Publishers   journal
# 4                                      Pensoft Publishers   journal
# ...                                                   ...       ...
# 199667  Research Center for Climate Change, University...   journal
# 199668  Research Center for Climate Change, University...   journal
# 199669  Museo Nacional de Historia Natural, Prof. Euge...   journal
# 199670  Alexander von Humboldt Biological Resources Re...   journal
# 199671  Alexander von Humboldt Biological Resources Re...   journal
#
#                                                  host_url is_host_oa  \
# 0       https://zookeys.pensoft.net/article/2702/downl...       True
# 1       https://zookeys.pensoft.net/article/2702/downl...       True
# 2       https://zookeys.pensoft.net/article/2702/downl...       True
# 3       https://zookeys.pensoft.net/article/2702/downl...       True
# 4       https://zookeys.pensoft.net/article/2702/downl...       True
# ...                                                   ...        ...
# 199667  http://tapro.sljol.info/articles/10.4038/tapro...       True
# 199668  http://tapro.sljol.info/articles/10.4038/tapro...       True
# 199669  http://novitatescaribaea.do/index.php/novitate...       True
# 199670           https://doi.org/10.21068/c2017.v18n02a19       True
# 199671           https://doi.org/10.21068/c2017.v18n02a19       True
#
#             host_version  host_license is_oa oa_status  \
# 0       publishedVersion         cc-by  True      gold
# 1       publishedVersion         cc-by  True      gold
# 2       publishedVersion         cc-by  True      gold
# 3       publishedVersion         cc-by  True      gold
# 4       publishedVersion         cc-by  True      gold
# ...                  ...           ...   ...       ...
# 199667  publishedVersion         cc-by  True    hybrid
# 199668  publishedVersion         cc-by  True    hybrid
# 199669  publishedVersion      cc-by-nc  True      gold
# 199670  publishedVersion   cc-by-nc-nd  True      gold
# 199671  publishedVersion   cc-by-nc-nd  True      gold
#
#                                                    oa_url
# 0       https://zookeys.pensoft.net/article/2702/downl...
# 1       https://zookeys.pensoft.net/article/2702/downl...
# 2       https://zookeys.pensoft.net/article/2702/downl...
# 3       https://zookeys.pensoft.net/article/2702/downl...
# 4       https://zookeys.pensoft.net/article/2702/downl...
# ...                                                   ...
# 199667  http://tapro.sljol.info/articles/10.4038/tapro...
# 199668  http://tapro.sljol.info/articles/10.4038/tapro...
# 199669  http://novitatescaribaea.do/index.php/novitate...
# 199670           https://doi.org/10.21068/c2017.v18n02a19
# 199671           https://doi.org/10.21068/c2017.v18n02a19
#
# [199672 rows x 56 columns]

# %%
singles_insects = get_single_authors(authors_insects)
singles_insects
# Out:
#                              article_id author_position  \
# 0      https://openalex.org/W2991362080           first
# 1      https://openalex.org/W3007928204           first
# 2      https://openalex.org/W2978240330          middle
# 3      https://openalex.org/W3015756137          middle
# 28     https://openalex.org/W2156582146          middle
# ...                                 ...             ...
# 91867  https://openalex.org/W4293109490           first
# 91868  https://openalex.org/W2511140662            last
# 91869  https://openalex.org/W3006371900          middle
# 91870  https://openalex.org/W3116948575          middle
# 91871  https://openalex.org/W2062110938            last
#
#                               author_id                author_display_name  \
# 0      https://openalex.org/A2313154617                 Marc F. DiGirolomo
# 1      https://openalex.org/A2524792898  Edgar Uriel Garduño-Montes de Oca
# 2      https://openalex.org/A2103720066           Violeta Llanes Hernández
# 3      https://openalex.org/A3012815696            Norbert Kouakou Kouadio
# 28     https://openalex.org/A2107906951                     Jung-Won Hwang
# ...                                 ...                                ...
# 91867  https://openalex.org/A2589635970                 Fernando Rodríguez
# 91868  https://openalex.org/A3030163424                        Xuefeng Qin
# 91869  https://openalex.org/A2720161091                       Victor Phani
# 91870  https://openalex.org/A2010641205              Christine Kerschbamer
# 91871  https://openalex.org/A2084269975              Govindasamy Rajakumar
#
#                                        orcid  \
# 0      https://orcid.org/0000-0001-7596-3109
# 1                                       None
# 2                                       None
# 3                                       None
# 28     https://orcid.org/0000-0002-0887-6889
# ...                                      ...
# 91867  https://orcid.org/0000-0002-7237-7443
# 91868                                   None
# 91869                                   None
# 91870                                   None
# 91871  https://orcid.org/0000-0002-5388-5813
#
#                                   raw_affiliation_string  \
# 0      (MFD) United States Forest Service, State and ...
# 1      Departamento de Biología Evolutiva, Facultad d...
# 2      Departamento de Ecología y Recursos Naturales,...
# 3
# 28     Animal, Plant & Fisheries Quarantine & Inspect...
# ...                                                  ...
# 91867
# 91868  Department of Plant Protection, Henan Institut...
# 91869  Division of Nematology, ICAR-Indian Agricultur...
# 91870  Laimburg Research Centre, Laimburg 6, Pfatten ...
# 91871  Unit of Nanotechnology and Bioactive Natural P...
#
#                                 inst_id  \
# 0      https://openalex.org/I1313416372
# 1         https://openalex.org/I8961855
# 2         https://openalex.org/I8961855
# 3                                  None
# 28     https://openalex.org/I4210160954
# ...                                 ...
# 91867                              None
# 91868  https://openalex.org/I4210163247
# 91869    https://openalex.org/I45509622
# 91870                              None
# 91871    https://openalex.org/I13754080
#
#                                        inst_display_name  \
# 0                                      US Forest Service
# 1               National Autonomous University of Mexico
# 2               National Autonomous University of Mexico
# 3                                                   None
# 28                    Animal and Plant Quarantine Agency
# ...                                                  ...
# 91867                                               None
# 91868          Henan Institute of Science and Technology
# 91869             Indian Agricultural Research Institute
# 91870  Laimburg Research Centre, Laimburg 6, Pfatten ...
# 91871                            C. Abdul Hakeem College
#
#                              ror inst_country_code  ...  \
# 0      https://ror.org/03zmjc935                US  ...
# 1      https://ror.org/01tmp8f25                MX  ...
# 2      https://ror.org/01tmp8f25                MX  ...
# 3                           None              None  ...
# 28     https://ror.org/04sbe6g90                KR  ...
# ...                          ...               ...  ...
# 91867                       None              None  ...
# 91868  https://ror.org/0578f1k82                CN  ...
# 91869  https://ror.org/01bzgdw81                IN  ...
# 91870                       None              None  ...
# 91871                       None                IN  ...
#
#                                        host_display_name  \
# 0      Proceedings of the Entomological Society of Wa...
# 1                                Journal of Parasitology
# 2                                Acta zoológica mexicana
# 3                                 Zoosystematica Rossica
# 28                                 African Invertebrates
# ...                                                  ...
# 91867              Кавказский энтомологический бюллетень
# 91868                                            ZooKeys
# 91869  HAL (Le Centre pour la Communication Scientifi...
# 91870                                            ZooKeys
# 91871                                Cretaceous Research
#
#                                                publisher   host_type  \
# 0           BioOne (Entomological Society of Washington)     journal
# 1                    American Society of Parasitologists     journal
# 2                            Instituto de Ecologia, A.C.     journal
# 3      Zoological Institute of the Russian Academy of...     journal
# 28                                    Pensoft Publishers     journal
# ...                                                  ...         ...
# 91867  Southern Scientific Center of the Russian Acad...     journal
# 91868                                 Pensoft Publishers     journal
# 91869  Le Centre pour la Communication Scientifique D...  repository
# 91870                                 Pensoft Publishers     journal
# 91871                                        Elsevier BV     journal
#
#                                                 host_url is_host_oa  \
# 0                                                   None      False
# 1                                                   None      False
# 2      https://azm.ojs.inecol.mx/index.php/azm/articl...       True
# 3                                                   None      False
# 28                 https://doi.org/10.5733/afin.056.0114       True
# ...                                                  ...        ...
# 91867  https://doi.org/10.23885/1814-3326-2012-8-1-21-23       True
# 91868  https://zookeys.pensoft.net/article/35532/down...       True
# 91869  https://hal.archives-ouvertes.fr/hal-03608424/...       True
# 91870  https://zookeys.pensoft.net/article/3539/downl...       True
# 91871                                               None      False
#
#            host_version  host_license  is_oa oa_status  \
# 0                  None          None  False    closed
# 1                  None          None  False    closed
# 2      publishedVersion   cc-by-nc-sa   True      gold
# 3                  None          None  False    closed
# 28     publishedVersion         cc-by   True      gold
# ...                 ...           ...    ...       ...
# 91867  publishedVersion          None   True    bronze
# 91868  publishedVersion         cc-by   True      gold
# 91869  submittedVersion          None   True     green
# 91870  publishedVersion         cc-by   True      gold
# 91871              None          None   True     green
#
#                                                   oa_url
# 0                                                   None
# 1                                                   None
# 2      https://azm.ojs.inecol.mx/index.php/azm/articl...
# 3                                                   None
# 28                 https://doi.org/10.5733/afin.056.0114
# ...                                                  ...
# 91867  https://doi.org/10.23885/1814-3326-2012-8-1-21-23
# 91868  https://zookeys.pensoft.net/article/35532/down...
# 91869  https://hal.archives-ouvertes.fr/hal-03608424/...
# 91870  https://zookeys.pensoft.net/article/3539/downl...
# 91871  https://research-information.bris.ac.uk/ws/fil...
#
# [47458 rows x 56 columns]

# %%
authors_insects.to_pickle("./data/all_authors_insect_articles_RLIT_method.pkl")
singles_insects.to_pickle("./data/authors_insect_articles_RLIT_method_no_duplicates.pkl")

# %%
eu_insects = pd.read_pickle("./data/RLIT_method_openalex_EU27_insect_articles.pkl")
eu_insects = get_dict_info(eu_insects)
eu_insects
# Out:
#                                     id  \
# 0     https://openalex.org/W2075105050
# 1     https://openalex.org/W2074050863
# 2     https://openalex.org/W2124627356
# 3     https://openalex.org/W2470267224
# 4     https://openalex.org/W2297951136
# ...                                ...
# 8119  https://openalex.org/W3000603933
# 8120  https://openalex.org/W2300829245
# 8121  https://openalex.org/W2792039220
# 8122  https://openalex.org/W4243684135
# 8123  https://openalex.org/W4246017557
#
#                                                     doi  \
# 0              https://doi.org/10.3897/zookeys.186.2947
# 1              https://doi.org/10.3897/zookeys.250.3715
# 2              https://doi.org/10.3161/000345411x622525
# 3                   https://doi.org/10.1017/jpa.2016.51
# 4              https://doi.org/10.3897/zookeys.572.6763
# ...                                                 ...
# 8119            https://doi.org/10.3390/insects11010051
# 8120  https://doi.org/10.1146/annurev-ento-010715-02...
# 8121                 https://doi.org/10.7717/peerj.5126
# 8122      https://doi.org/10.7287/peerj.preprints.26662
# 8123    https://doi.org/10.7287/peerj.preprints.26662v1
#
#                                                   title  \
# 0     New species and distributional records of Aleo...
# 1     Introduction of the Exocelina ekari-group with...
# 2     A New Species ofHenosepilachnaLi (Coleoptera: ...
# 3     New species from Late Cretaceous New Jersey am...
# 4     A contribution to the knowledge of the mountai...
# ...                                                 ...
# 8119  Molecular Phylogeny and Infraordinal Classific...
# 8120  Structure and Evolution of Insect Sperm: New I...
# 8121  A reference cytochrome c oxidase subunit I dat...
# 8122  A reference cytochrome c oxidase subunit I dat...
# 8123  A reference cytochrome c oxidase subunit I dat...
#
#                                            display_name  relevance_score  \
# 0     New species and distributional records of Aleo...        186.24031
# 1     Introduction of the Exocelina ekari-group with...        134.67500
# 2     A New Species ofHenosepilachnaLi (Coleoptera: ...        118.18758
# 3     New species from Late Cretaceous New Jersey am...        113.15040
# 4     A contribution to the knowledge of the mountai...        109.41350
# ...                                                 ...              ...
# 8119  Molecular Phylogeny and Infraordinal Classific...        115.29168
# 8120  Structure and Evolution of Insect Sperm: New I...        341.63333
# 8121  A reference cytochrome c oxidase subunit I dat...        118.58033
# 8122  A reference cytochrome c oxidase subunit I dat...              NaN
# 8123  A reference cytochrome c oxidase subunit I dat...              NaN
#
#       publication_year publication_date  \
# 0                 2012       2012-04-26
# 1                 2012       2012-12-13
# 2                 2011       2011-12-01
# 3                 2016       2016-08-23
# 4                 2016       2016-03-15
# ...                ...              ...
# 8119              2020       2020-01-12
# 8120              2016       2016-03-16
# 8121              2018       2018-06-26
# 8122              2018       2018-03-12
# 8123              2018       2018-03-12
#
#                                                     ids  \
# 0     {'openalex': 'https://openalex.org/W2075105050...
# 1     {'openalex': 'https://openalex.org/W2074050863...
# 2     {'openalex': 'https://openalex.org/W2124627356...
# 3     {'openalex': 'https://openalex.org/W2470267224...
# 4     {'openalex': 'https://openalex.org/W2297951136...
# ...                                                 ...
# 8119  {'openalex': 'https://openalex.org/W3000603933...
# 8120  {'openalex': 'https://openalex.org/W2300829245...
# 8121  {'openalex': 'https://openalex.org/W2792039220...
# 8122  {'openalex': 'https://openalex.org/W4243684135...
# 8123  {'openalex': 'https://openalex.org/W4246017557...
#
#                                        primary_location  \
# 0     {'is_oa': True, 'landing_page_url': 'https://d...
# 1     {'is_oa': True, 'landing_page_url': 'https://d...
# 2     {'is_oa': None, 'landing_page_url': 'https://d...
# 3     {'is_oa': None, 'landing_page_url': 'https://d...
# 4     {'is_oa': True, 'landing_page_url': 'https://d...
# ...                                                 ...
# 8119  {'is_oa': True, 'landing_page_url': 'https://d...
# 8120  {'is_oa': None, 'landing_page_url': 'https://d...
# 8121  {'is_oa': True, 'landing_page_url': 'https://d...
# 8122  {'is_oa': None, 'landing_page_url': 'https://d...
# 8123  {'is_oa': None, 'landing_page_url': 'https://d...
#
#                                              host_venue  ...  \
# 0     {'id': 'https://openalex.org/S199213172', 'iss...  ...
# 1     {'id': 'https://openalex.org/S199213172', 'iss...  ...
# 2     {'id': 'https://openalex.org/S24891482', 'issn...  ...
# 3     {'id': 'https://openalex.org/S143791635', 'iss...  ...
# 4     {'id': 'https://openalex.org/S199213172', 'iss...  ...
# ...                                                 ...  ...
# 8119  {'id': 'https://openalex.org/S28057480', 'issn...  ...
# 8120  {'id': 'https://openalex.org/S92576693', 'issn...  ...
# 8121  {'id': 'https://openalex.org/S1983995261', 'is...  ...
# 8122  {'id': None, 'issn_l': None, 'issn': None, 'di...  ...
# 8123  {'id': None, 'issn_l': None, 'issn': None, 'di...  ...
#
#                 host_display_name                   publisher host_type  \
# 0                         ZooKeys          Pensoft Publishers   journal
# 1                         ZooKeys          Pensoft Publishers   journal
# 2               Annales Zoologici  Polish Academy of Sciences   journal
# 3         Journal of Paleontology     Paleontological Society   journal
# 4                         ZooKeys          Pensoft Publishers   journal
# ...                           ...                         ...       ...
# 8119                      Insects                        MDPI   journal
# 8120  Annual Review of Entomology              Annual Reviews   journal
# 8121                        PeerJ                 PeerJ, Inc.   journal
# 8122                         None                        None      None
# 8123                         None                        None      None
#
#                                                host_url is_host_oa  \
# 0     https://zookeys.pensoft.net/article/2702/downl...       True
# 1     https://zookeys.pensoft.net/article/3440/downl...       True
# 2                                                  None      False
# 3                                                  None      False
# 4     https://zookeys.pensoft.net/article/6763/downl...       True
# ...                                                 ...        ...
# 8119  https://www.mdpi.com/2075-4450/11/1/51/pdf?ver...       True
# 8120                                               None      False
# 8121                 https://doi.org/10.7717/peerj.5126       True
# 8122      https://doi.org/10.7287/peerj.preprints.26662      False
# 8123    https://doi.org/10.7287/peerj.preprints.26662v1      False
#
#           host_version host_license  is_oa oa_status  \
# 0     publishedVersion        cc-by   True      gold
# 1     publishedVersion        cc-by   True      gold
# 2                 None         None  False    closed
# 3                 None         None  False    closed
# 4     publishedVersion        cc-by   True      gold
# ...                ...          ...    ...       ...
# 8119  publishedVersion        cc-by   True      gold
# 8120              None         None  False    closed
# 8121  publishedVersion        cc-by   True      gold
# 8122              None         None   True     green
# 8123              None         None   True     green
#
#                                                  oa_url
# 0     https://zookeys.pensoft.net/article/2702/downl...
# 1     https://zookeys.pensoft.net/article/3440/downl...
# 2                                                  None
# 3                                                  None
# 4     https://zookeys.pensoft.net/article/6763/downl...
# ...                                                 ...
# 8119  https://www.mdpi.com/2075-4450/11/1/51/pdf?ver...
# 8120                                               None
# 8121                 https://doi.org/10.7717/peerj.5126
# 8122  https://europepmc.org/articles/pmc6025149?pdf=...
# 8123  https://europepmc.org/articles/pmc6025149?pdf=...
#
# [8124 rows x 45 columns]

# %%
eu_insect_authors = get_authors(eu_insects)
eu_insect_authors
# Out:
#                              article_id author_position  \
# 0      https://openalex.org/W2075105050           first
# 1      https://openalex.org/W2075105050          middle
# 2      https://openalex.org/W2075105050          middle
# 3      https://openalex.org/W2075105050          middle
# 4      https://openalex.org/W2075105050          middle
# ...                                 ...             ...
# 44683  https://openalex.org/W4243684135            last
# 44684  https://openalex.org/W4246017557           first
# 44685  https://openalex.org/W4246017557          middle
# 44686  https://openalex.org/W4246017557          middle
# 44687  https://openalex.org/W4246017557            last
#
#                               author_id    author_display_name  \
# 0      https://openalex.org/A2634481662            Adam Brunke
# 1      https://openalex.org/A1954442483       Jan Klimaszewski
# 2      https://openalex.org/A2592732627      Julie-Anne Dorval
# 3      https://openalex.org/A2021629399       Caroline Bourdon
# 4      https://openalex.org/A1430890116           S. M. Paiero
# ...                                 ...                    ...
# 44683  https://openalex.org/A2168305379        Reed F. Johnson
# 44684  https://openalex.org/A2270236954   Rodney T. Richardson
# 44685    https://openalex.org/A79282783  Johan Bengtsson-Palme
# 44686  https://openalex.org/A2237159663       Mary M. Gardiner
# 44687  https://openalex.org/A2168305379        Reed F. Johnson
#
#                                        orcid  \
# 0      https://orcid.org/0000-0003-1158-936X
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ...                                      ...
# 44683  https://orcid.org/0000-0002-4312-0550
# 44684  https://orcid.org/0000-0002-4443-1705
# 44685  https://orcid.org/0000-0002-6528-3158
# 44686  https://orcid.org/0000-0003-1796-6146
# 44687  https://orcid.org/0000-0002-4312-0550
#
#                                   raw_affiliation_string  \
# 0      Zoological Museum (Natural History Museum of D...
# 1
# 2
# 3
# 4
# ...                                                  ...
# 44683  Department of Entomology, Ohio State Universit...
# 44684  Department of Entomology, Ohio State Universit...
# 44685  Department of Infectious Diseases, Institute o...
# 44686  Department of Entomology, Ohio State Universit...
# 44687  Department of Entomology, Ohio State Universit...
#
#                                 inst_id  \
# 0      https://openalex.org/I4210110903
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
# ...                                 ...
# 44683                              None
# 44684    https://openalex.org/I52357470
# 44685   https://openalex.org/I881427289
# 44686    https://openalex.org/I52357470
# 44687                              None
#
#                                        inst_display_name  \
# 0                                 Natural History Museum
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 44683  Department of Entomology, Ohio State Universit...
# 44684                          The Ohio State University
# 44685                           University of Gothenburg
# 44686                          The Ohio State University
# 44687  Department of Entomology, Ohio State Universit...
#
#                              ror inst_country_code  ... host_display_name  \
# 0      https://ror.org/0166x0j30                DK  ...           ZooKeys
# 1                           None              None  ...           ZooKeys
# 2                           None              None  ...           ZooKeys
# 3                           None              None  ...           ZooKeys
# 4                           None              None  ...           ZooKeys
# ...                          ...               ...  ...               ...
# 44683                       None              None  ...              None
# 44684  https://ror.org/00rs6vg23                US  ...              None
# 44685  https://ror.org/01tm6cn81                SE  ...              None
# 44686  https://ror.org/00rs6vg23                US  ...              None
# 44687                       None              None  ...              None
#
#                 publisher host_type  \
# 0      Pensoft Publishers   journal
# 1      Pensoft Publishers   journal
# 2      Pensoft Publishers   journal
# 3      Pensoft Publishers   journal
# 4      Pensoft Publishers   journal
# ...                   ...       ...
# 44683                None      None
# 44684                None      None
# 44685                None      None
# 44686                None      None
# 44687                None      None
#
#                                                 host_url is_host_oa  \
# 0      https://zookeys.pensoft.net/article/2702/downl...       True
# 1      https://zookeys.pensoft.net/article/2702/downl...       True
# 2      https://zookeys.pensoft.net/article/2702/downl...       True
# 3      https://zookeys.pensoft.net/article/2702/downl...       True
# 4      https://zookeys.pensoft.net/article/2702/downl...       True
# ...                                                  ...        ...
# 44683      https://doi.org/10.7287/peerj.preprints.26662      False
# 44684    https://doi.org/10.7287/peerj.preprints.26662v1      False
# 44685    https://doi.org/10.7287/peerj.preprints.26662v1      False
# 44686    https://doi.org/10.7287/peerj.preprints.26662v1      False
# 44687    https://doi.org/10.7287/peerj.preprints.26662v1      False
#
#            host_version  host_license is_oa oa_status  \
# 0      publishedVersion         cc-by  True      gold
# 1      publishedVersion         cc-by  True      gold
# 2      publishedVersion         cc-by  True      gold
# 3      publishedVersion         cc-by  True      gold
# 4      publishedVersion         cc-by  True      gold
# ...                 ...           ...   ...       ...
# 44683              None          None  True     green
# 44684              None          None  True     green
# 44685              None          None  True     green
# 44686              None          None  True     green
# 44687              None          None  True     green
#
#                                                   oa_url
# 0      https://zookeys.pensoft.net/article/2702/downl...
# 1      https://zookeys.pensoft.net/article/2702/downl...
# 2      https://zookeys.pensoft.net/article/2702/downl...
# 3      https://zookeys.pensoft.net/article/2702/downl...
# 4      https://zookeys.pensoft.net/article/2702/downl...
# ...                                                  ...
# 44683  https://europepmc.org/articles/pmc6025149?pdf=...
# 44684  https://europepmc.org/articles/pmc6025149?pdf=...
# 44685  https://europepmc.org/articles/pmc6025149?pdf=...
# 44686  https://europepmc.org/articles/pmc6025149?pdf=...
# 44687  https://europepmc.org/articles/pmc6025149?pdf=...
#
# [44688 rows x 56 columns]

# %%
only_eu_insect_authors = get_european_authors(eu_insect_authors, pan_europe=False)
only_eu_insect_authors
# Out:
#        Index                        article_id author_position  \
# 0          0  https://openalex.org/W2075105050           first
# 1          6  https://openalex.org/W2074050863           first
# 2         10  https://openalex.org/W2124627356           first
# 3         11  https://openalex.org/W2470267224           first
# 4         12  https://openalex.org/W2470267224            last
# ...      ...                               ...             ...
# 25255  44674  https://openalex.org/W3000603933          middle
# 25256  44675  https://openalex.org/W3000603933            last
# 25257  44677  https://openalex.org/W2792039220          middle
# 25258  44681  https://openalex.org/W4243684135          middle
# 25259  44685  https://openalex.org/W4246017557          middle
#
#                               author_id    author_display_name  \
# 0      https://openalex.org/A2634481662            Adam Brunke
# 1        https://openalex.org/A58389920        Helena Shaverdo
# 2      https://openalex.org/A1616833297         Karol Szawaryn
# 3      https://openalex.org/A2309831076            David Peris
# 4      https://openalex.org/A2225365894              Jiří Háva
# ...                                 ...                    ...
# 25255  https://openalex.org/A1210563886            Ivona Horká
# 25256  https://openalex.org/A1908576969         Robin Kundrata
# 25257    https://openalex.org/A79282783  Johan Bengtsson-Palme
# 25258    https://openalex.org/A79282783  Johan Bengtsson-Palme
# 25259    https://openalex.org/A79282783  Johan Bengtsson-Palme
#
#                                        orcid  \
# 0      https://orcid.org/0000-0003-1158-936X
# 1      https://orcid.org/0000-0001-5034-7342
# 2      https://orcid.org/0000-0002-9329-4268
# 3      https://orcid.org/0000-0001-9912-8802
# 4                                       None
# ...                                      ...
# 25255  https://orcid.org/0000-0002-8942-9481
# 25256  https://orcid.org/0000-0001-9397-1030
# 25257  https://orcid.org/0000-0002-6528-3158
# 25258  https://orcid.org/0000-0002-6528-3158
# 25259  https://orcid.org/0000-0002-6528-3158
#
#                                   raw_affiliation_string  \
# 0      Zoological Museum (Natural History Museum of D...
# 1      Naturhistorisches Museum, Burgring 7, A-1010 V...
# 2      Museum and Institute of Zoology, Polish Academ...
# 3                              Universitat  de Barcelona
# 4         Czech University of Life Sciences Kamýcká 1176
# ...                                                  ...
# 25255  Department of Biology and Ecology and Institut...
# 25256  Department of Zoology, Faculty of Science, Pal...
# 25257  Department of Infectious Diseases, Institute o...
# 25258  Department of Infectious Diseases, Institute o...
# 25259  Department of Infectious Diseases, Institute o...
#
#                                 inst_id  \
# 0      https://openalex.org/I4210110903
# 1      https://openalex.org/I1279955124
# 2      https://openalex.org/I2802889272
# 3        https://openalex.org/I71999127
# 4       https://openalex.org/I205984670
# ...                                 ...
# 25255   https://openalex.org/I187293425
# 25256    https://openalex.org/I70703428
# 25257   https://openalex.org/I881427289
# 25258   https://openalex.org/I881427289
# 25259   https://openalex.org/I881427289
#
#                               inst_display_name                        ror  \
# 0                        Natural History Museum  https://ror.org/0166x0j30
# 1                 Natural History Museum Vienna  https://ror.org/01tv5y993
# 2               Museum and Institute of Zoology  https://ror.org/00r9k8q20
# 3                       University of Barcelona  https://ror.org/021018s57
# 4      Czech University of Life Sciences Prague  https://ror.org/0415vcw02
# ...                                         ...                        ...
# 25255                     University of Ostrava  https://ror.org/00pyqav47
# 25256               Palacký University, Olomouc  https://ror.org/04qxnmv42
# 25257                  University of Gothenburg  https://ror.org/01tm6cn81
# 25258                  University of Gothenburg  https://ror.org/01tm6cn81
# 25259                  University of Gothenburg  https://ror.org/01tm6cn81
#
#        ...        host_display_name                   publisher host_type  \
# 0      ...                  ZooKeys          Pensoft Publishers   journal
# 1      ...                  ZooKeys          Pensoft Publishers   journal
# 2      ...        Annales Zoologici  Polish Academy of Sciences   journal
# 3      ...  Journal of Paleontology     Paleontological Society   journal
# 4      ...  Journal of Paleontology     Paleontological Society   journal
# ...    ...                      ...                         ...       ...
# 25255  ...                  Insects                        MDPI   journal
# 25256  ...                  Insects                        MDPI   journal
# 25257  ...                    PeerJ                 PeerJ, Inc.   journal
# 25258  ...                     None                        None      None
# 25259  ...                     None                        None      None
#
#                                                 host_url is_host_oa  \
# 0      https://zookeys.pensoft.net/article/2702/downl...       True
# 1      https://zookeys.pensoft.net/article/3440/downl...       True
# 2                                                   None      False
# 3                                                   None      False
# 4                                                   None      False
# ...                                                  ...        ...
# 25255  https://www.mdpi.com/2075-4450/11/1/51/pdf?ver...       True
# 25256  https://www.mdpi.com/2075-4450/11/1/51/pdf?ver...       True
# 25257                 https://doi.org/10.7717/peerj.5126       True
# 25258      https://doi.org/10.7287/peerj.preprints.26662      False
# 25259    https://doi.org/10.7287/peerj.preprints.26662v1      False
#
#            host_version  host_license  is_oa oa_status  \
# 0      publishedVersion         cc-by   True      gold
# 1      publishedVersion         cc-by   True      gold
# 2                  None          None  False    closed
# 3                  None          None  False    closed
# 4                  None          None  False    closed
# ...                 ...           ...    ...       ...
# 25255  publishedVersion         cc-by   True      gold
# 25256  publishedVersion         cc-by   True      gold
# 25257  publishedVersion         cc-by   True      gold
# 25258              None          None   True     green
# 25259              None          None   True     green
#
#                                                   oa_url
# 0      https://zookeys.pensoft.net/article/2702/downl...
# 1      https://zookeys.pensoft.net/article/3440/downl...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 25255  https://www.mdpi.com/2075-4450/11/1/51/pdf?ver...
# 25256  https://www.mdpi.com/2075-4450/11/1/51/pdf?ver...
# 25257                 https://doi.org/10.7717/peerj.5126
# 25258  https://europepmc.org/articles/pmc6025149?pdf=...
# 25259  https://europepmc.org/articles/pmc6025149?pdf=...
#
# [25260 rows x 57 columns]

# %%
eu_single_insect_authors = get_single_authors(only_eu_insect_authors)
eu_single_insect_authors
# Out:
#        Index                        article_id author_position  \
# 0      42085  https://openalex.org/W2023336202           first
# 1      40301  https://openalex.org/W1945992140           first
# 2      19622  https://openalex.org/W2338054385          middle
# 6       2532  https://openalex.org/W2563782945          middle
# 7      28179  https://openalex.org/W2101470019          middle
# ...      ...                               ...             ...
# 12501  16711  https://openalex.org/W2120745015          middle
# 12510  17020  https://openalex.org/W2275215172            last
# 12511   5413  https://openalex.org/W2925408631          middle
# 12512  33360  https://openalex.org/W2918328222            last
# 12513  42829  https://openalex.org/W2979124521            last
#
#                               author_id      author_display_name  \
# 0      https://openalex.org/A2887022682               Ivan Juric
# 1      https://openalex.org/A2494006551         Pietro Lo Cascio
# 2      https://openalex.org/A2290164705  Andrea Carolina Wanumen
# 6      https://openalex.org/A2286190915             Julio Ferrer
# 7      https://openalex.org/A2558964123          Magdalena Witek
# ...                                 ...                      ...
# 12501  https://openalex.org/A1402554243             Örjan Östman
# 12510  https://openalex.org/A2132235658           Andrzej Wolski
# 12511  https://openalex.org/A1543142765         Szymon Chowański
# 12512  https://openalex.org/A2784830561            S. V. Kovalev
# 12513  https://openalex.org/A2555322479        Bernard R. Landau
#
#                                        orcid  \
# 0                                       None
# 1                                       None
# 2                                       None
# 6                                       None
# 7      https://orcid.org/0000-0002-6172-8981
# ...                                      ...
# 12501  https://orcid.org/0000-0002-1930-0148
# 12510                                   None
# 12511  https://orcid.org/0000-0002-5667-1781
# 12512                                   None
# 12513                                   None
#
#                                   raw_affiliation_string  \
# 0      Research Institute of Organic Agriculture (FiB...
# 1           Nesos - Island Biodiversity Research, Lipari
# 2      Departamento de Protección de Cultivos, Escuel...
# 6      2Departement of Zoology, Swedish Museum of Nat...
# 7      Department of Animal and Human Biology, Univer...
# ...                                                  ...
# 12501    Evolutionary Biology Centre. Uppsala University
# 12510  Department of Biosystematics, Opole University...
# 12511  Department of Animal Physiology and Developmen...
# 12512                    Parkovaya str. 38, Dolgoprudnyi
# 12513
#
#                                 inst_id  \
# 0        https://openalex.org/I79093821
# 1      https://openalex.org/I1295562517
# 2        https://openalex.org/I88060688
# 6      https://openalex.org/I2801711128
# 7        https://openalex.org/I55143463
# ...                                 ...
# 12501   https://openalex.org/I123387679
# 12510   https://openalex.org/I170583851
# 12511    https://openalex.org/I59411706
# 12512    https://openalex.org/I88459447
# 12513  https://openalex.org/I1295562517
#
#                                inst_display_name                        ror  \
# 0      Research Institute of Organic Agriculture  https://ror.org/03jmahf97
# 1                  Naturalis Biodiversity Center  https://ror.org/0566bfb96
# 2                 Technical University of Madrid  https://ror.org/03n6nwv02
# 6              Swedish Museum of Natural History  https://ror.org/05k323c76
# 7                            University of Turin  https://ror.org/048tbm396
# ...                                          ...                        ...
# 12501                         Uppsala University  https://ror.org/048a87296
# 12510                           Opole University  https://ror.org/04gbpnx96
# 12511       Adam Mickiewicz University in Poznań  https://ror.org/04g6bbq64
# 12512                                      Novay  https://ror.org/00266dp40
# 12513              Naturalis Biodiversity Center  https://ror.org/0566bfb96
#
#        ...                   host_display_name  \
# 0      ...                          Biocontrol
# 1      ...              Fragmenta entomologica
# 2      ...                             Insects
# 6      ...                   Annales Zoologici
# 7      ...               Ecological Entomology
# ...    ...                                 ...
# 12501  ...  Bulletin of Entomological Research
# 12510  ...                             Zootaxa
# 12511  ...             Frontiers in Physiology
# 12512  ...        Ukrainian Journal of Ecology
# 12513  ...                             Zootaxa
#
#                              publisher host_type  \
# 0      Springer Science+Business Media   journal
# 1                    PAGEPress (Italy)   journal
# 2                                 MDPI   journal
# 6           Polish Academy of Sciences   journal
# 7          Royal Entomological Society   journal
# ...                                ...       ...
# 12501       Cambridge University Press   journal
# 12510                        Q15088586   journal
# 12511                  Frontiers Media   journal
# 12512         Alex Matsyura Publishing   journal
# 12513                        Q15088586   journal
#
#                                                 host_url is_host_oa  \
# 0                                                   None      False
# 1                     https://doi.org/10.4081/fe.2014.76       True
# 2              https://www.mdpi.com/2075-4450/7/2/15/pdf       True
# 6                                                   None      False
# 7                                                   None      False
# ...                                                  ...        ...
# 12501                                               None      False
# 12510                                               None      False
# 12511  https://www.frontiersin.org/articles/10.3389/f...       True
# 12512  http://ojs.mdpu.org.ua/index.php/biol/article/...      False
# 12513                                               None      False
#
#            host_version  host_license  is_oa oa_status  \
# 0                  None          None   True     green
# 1      publishedVersion      cc-by-nc   True      gold
# 2      publishedVersion         cc-by   True      gold
# 6                  None          None  False    closed
# 7                  None          None  False    closed
# ...                 ...           ...    ...       ...
# 12501              None          None  False    closed
# 12510              None          None  False    closed
# 12511  publishedVersion         cc-by   True      gold
# 12512              None          None  False      None
# 12513              None          None  False    closed
#
#                                                   oa_url
# 0      http://doc.rero.ch/record/330962/files/10526_2...
# 1                     https://doi.org/10.4081/fe.2014.76
# 2      https://www.mdpi.com/2075-4450/7/2/15/pdf?vers...
# 6                                                   None
# 7                                                   None
# ...                                                  ...
# 12501                                               None
# 12510                                               None
# 12511  https://www.frontiersin.org/articles/10.3389/f...
# 12512                                               None
# 12513                                               None
#
# [6371 rows x 57 columns]

# %%
only_eu_insect_authors.to_pickle("./data/EU27_all_authors_insect_articles_RLIT_method.pkl")
eu_single_insect_authors.to_pickle("./data/EU27_authors_insect_articles_RLIT_method_no_duplicates.pkl")
