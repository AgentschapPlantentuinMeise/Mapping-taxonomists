# %% [markdown]
# # 1. Using OpenAlex to find taxonomists

# %% [markdown]
# ## 1.3. Filter journal articles for accuracy
#
# Not all articles in taxonomic journals are strictly "taxonomical" (describing new species). Some are about methodology or further research into specific organisms. To remedy this, we searched our list of articles for terms similar to the WoS comparison search terms, adding "nov" and dropping the order name.

# %%
import numpy as np
import pandas as pd
import pickle
import openalex

# %%
# filter all found articles
articles = pd.read_pickle("./data/articles_global_with_taxonomy_concept_in_journal.pkl")
filtered_articles = openalex.filter_keywords(articles)
filtered_articles
# Out:
#                                      id  \
# 0      https://openalex.org/W2097461610
# 1      https://openalex.org/W2098184878
# 2      https://openalex.org/W1841372523
# 3       https://openalex.org/W813610620
# 4      https://openalex.org/W2581956133
# ...                                 ...
# 50603  https://openalex.org/W4316923273
# 50604  https://openalex.org/W4316923294
# 50605  https://openalex.org/W4316923321
# 50606  https://openalex.org/W4316923341
# 50607  https://openalex.org/W4316923342
#
#                                                      doi  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 50603  https://doi.org/10.21684/0132-8077-2022-30-2-2...
# 50604  https://doi.org/10.21684/0132-8077-2022-30-2-1...
# 50605  https://doi.org/10.21684/0132-8077-2022-30-2-2...
# 50606  https://doi.org/10.21684/0132-8077-2022-30-2-2...
# 50607  https://doi.org/10.21684/0132-8077-2022-30-2-1...
#
#                                                    title  \
# 0      A systematic monograph of the Recent Pentastom...
# 1      Mycale species (Porifera: Poecilosclerida) of ...
# 2      Dinotrema brevis spec. nov. (Hymenoptera: Brac...
# 3      Sigalphus anjae spec. nov. (Hymenoptera: Braco...
# 4      Land snails of the islet of Misali, off Pemba ...
# ...                                                  ...
# 50603  REDESCRIPTION OF TYPHLODROMUS (ANTHOSEIUS) KUZ...
# 50604  THE MITE GENUS HISTIOGASTER (ACARI: ACARIDAE) ...
# 50605  A NEW LARVAL SPECIES OF THE GENUS SMARIS (SMAR...
# 50606  FIRST RECORD OF ADAMYSTIDAE (ACARI: PROSTIGMAT...
# 50607  NEW DATA ON THE FAUNA OF STIGMAEIDAE (ACARI: P...
#
#                                             display_name  publication_year  \
# 0      A systematic monograph of the Recent Pentastom...              2013
# 1      Mycale species (Porifera: Poecilosclerida) of ...              2014
# 2      Dinotrema brevis spec. nov. (Hymenoptera: Brac...              2014
# 3      Sigalphus anjae spec. nov. (Hymenoptera: Braco...              2014
# 4      Land snails of the islet of Misali, off Pemba ...              2013
# ...                                                  ...               ...
# 50603  REDESCRIPTION OF TYPHLODROMUS (ANTHOSEIUS) KUZ...              2022
# 50604  THE MITE GENUS HISTIOGASTER (ACARI: ACARIDAE) ...              2022
# 50605  A NEW LARVAL SPECIES OF THE GENUS SMARIS (SMAR...              2022
# 50606  FIRST RECORD OF ADAMYSTIDAE (ACARI: PROSTIGMAT...              2022
# 50607  NEW DATA ON THE FAUNA OF STIGMAEIDAE (ACARI: P...              2022
#
#       publication_date                                                ids  \
# 0           2013-01-01  {'openalex': 'https://openalex.org/W2097461610...
# 1           2014-01-01  {'openalex': 'https://openalex.org/W2098184878...
# 2           2014-01-01  {'openalex': 'https://openalex.org/W1841372523...
# 3           2014-01-01  {'openalex': 'https://openalex.org/W813610620'...
# 4           2013-01-01  {'openalex': 'https://openalex.org/W2581956133...
# ...                ...                                                ...
# 50603       2022-01-01  {'openalex': 'https://openalex.org/W4316923273...
# 50604       2022-01-01  {'openalex': 'https://openalex.org/W4316923294...
# 50605       2022-01-01  {'openalex': 'https://openalex.org/W4316923321...
# 50606       2022-01-01  {'openalex': 'https://openalex.org/W4316923341...
# 50607       2022-01-01  {'openalex': 'https://openalex.org/W4316923342...
#
#       language                                   primary_location  \
# 0           en  {'is_oa': False, 'landing_page_url': 'https://...
# 1           en  {'is_oa': False, 'landing_page_url': 'http://w...
# 2           en  {'is_oa': False, 'landing_page_url': 'https://...
# 3           en  {'is_oa': False, 'landing_page_url': 'https://...
# 4           en  {'is_oa': False, 'landing_page_url': 'https://...
# ...        ...                                                ...
# 50603       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 50604       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 50605       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 50606       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 50607       en  {'is_oa': True, 'landing_page_url': 'https://d...
#
#                   type  ...  \
# 0      journal-article  ...
# 1      journal-article  ...
# 2      journal-article  ...
# 3      journal-article  ...
# 4      journal-article  ...
# ...                ...  ...
# 50603  journal-article  ...
# 50604  journal-article  ...
# 50605  journal-article  ...
# 50606  journal-article  ...
# 50607  journal-article  ...
#
#                                                   grants  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 50603  [{'funder': 'https://openalex.org/F4320324099'...
# 50604                                                 []
# 50605  [{'funder': 'https://openalex.org/F4320321091'...
# 50606                                                 []
# 50607  [{'funder': 'https://openalex.org/F4320324099'...
#
#                                         referenced_works  \
# 0                                                     []
# 1      [https://openalex.org/W5267670, https://openal...
# 2      [https://openalex.org/W38046216, https://opena...
# 3      [https://openalex.org/W1537125554, https://ope...
# 4                                                     []
# ...                                                  ...
# 50603  [https://openalex.org/W1964529878, https://ope...
# 50604  [https://openalex.org/W1550069160, https://ope...
# 50605  [https://openalex.org/W800259873, https://open...
# 50606  [https://openalex.org/W1534787709, https://ope...
# 50607  [https://openalex.org/W340715479, https://open...
#
#                                            related_works  \
# 0      [https://openalex.org/W1451478857, https://ope...
# 1      [https://openalex.org/W1870150722, https://ope...
# 2      [https://openalex.org/W893905258, https://open...
# 3                                                     []
# 4                     [https://openalex.org/W3159842438]
# ...                                                  ...
# 50603  [https://openalex.org/W2075568141, https://ope...
# 50604  [https://openalex.org/W1977168516, https://ope...
# 50605  [https://openalex.org/W570431877, https://open...
# 50606  [https://openalex.org/W876471368, https://open...
# 50607  [https://openalex.org/W252732053, https://open...
#
#                                               ngrams_url  \
# 0      https://api.openalex.org/works/W2097461610/ngrams
# 1      https://api.openalex.org/works/W2098184878/ngrams
# 2      https://api.openalex.org/works/W1841372523/ngrams
# 3       https://api.openalex.org/works/W813610620/ngrams
# 4      https://api.openalex.org/works/W2581956133/ngrams
# ...                                                  ...
# 50603  https://api.openalex.org/works/W4316923273/ngrams
# 50604  https://api.openalex.org/works/W4316923294/ngrams
# 50605  https://api.openalex.org/works/W4316923321/ngrams
# 50606  https://api.openalex.org/works/W4316923341/ngrams
# 50607  https://api.openalex.org/works/W4316923342/ngrams
#
#                                  abstract_inverted_index  \
# 0      {'We': [0], 'compile': [1], 'all': [2], 'publi...
# 1      {'Based': [0], 'on': [1], 'collections': [2, 5...
# 2      {'A': [0, 17], 'new': [1], 'species': [2, 21],...
# 3      {'A': [0, 20], 'new': [1], 'species': [2, 25],...
# 4      {'A': [0], 'litter': [1], 'sample': [2], 'coll...
# ...                                                  ...
# 50603  {'Typhlodromus': [0], '(Anthoseius)': [1], 'ku...
# 50604  {'Two': [0], 'new': [1], 'species': [2, 61, 75...
# 50605  {'Here,': [0], 'we': [1], 'describe': [2], 'a'...
# 50606  {'The': [0], 'family': [1], 'Adamystidae': [2]...
# 50607  {'During': [0], 'the': [1, 8, 16, 50, 57, 60, ...
#
#                                         cited_by_api_url  \
# 0      https://api.openalex.org/works?filter=cites:W2...
# 1      https://api.openalex.org/works?filter=cites:W2...
# 2      https://api.openalex.org/works?filter=cites:W1...
# 3      https://api.openalex.org/works?filter=cites:W8...
# 4      https://api.openalex.org/works?filter=cites:W2...
# ...                                                  ...
# 50603  https://api.openalex.org/works?filter=cites:W4...
# 50604  https://api.openalex.org/works?filter=cites:W4...
# 50605  https://api.openalex.org/works?filter=cites:W4...
# 50606  https://api.openalex.org/works?filter=cites:W4...
# 50607  https://api.openalex.org/works?filter=cites:W4...
#
#                                           counts_by_year  \
# 0      [{'year': 2020, 'cited_by_count': 1}, {'year':...
# 1      [{'year': 2017, 'cited_by_count': 1}, {'year':...
# 2                  [{'year': 2019, 'cited_by_count': 1}]
# 3                  [{'year': 2016, 'cited_by_count': 1}]
# 4                                                     []
# ...                                                  ...
# 50603                                                 []
# 50604                                                 []
# 50605                                                 []
# 50606                                                 []
# 50607                                                 []
#
#                      updated_date  created_date is_authors_truncated
# 0      2023-06-01T01:06:38.350874    2016-06-24                  NaN
# 1      2023-05-26T23:14:12.444095    2016-06-24                  NaN
# 2      2023-05-27T02:13:06.320098    2016-06-24                  NaN
# 3      2023-05-26T07:36:47.829660    2016-06-24                  NaN
# 4      2023-05-27T01:55:15.761329    2017-02-03                  NaN
# ...                           ...           ...                  ...
# 50603  2023-05-29T11:27:36.010166    2023-01-18                  NaN
# 50604  2023-05-30T07:43:48.170462    2023-01-18                  NaN
# 50605  2023-05-31T13:50:18.657480    2023-01-18                  NaN
# 50606  2023-06-01T12:05:38.865862    2023-01-18                  NaN
# 50607  2023-06-01T12:46:41.601160    2023-01-18                  NaN
#
# [50608 rows x 34 columns]

# %%
filtered_articles.to_pickle("./data/keyword_filtered_articles_global_with_taxonomy_concept_in_journal.pkl")

# %%
# filter EU27 articles
eu_articles = pd.read_pickle("./data/articles_EU27_with_taxonomy_concept_in_journal.pkl")
filtered_eu_articles = openalex.filter_keywords(eu_articles)
filtered_eu_articles
# Out:
#                                      id  \
# 0      https://openalex.org/W2282635459
# 1      https://openalex.org/W1534942643
# 2      https://openalex.org/W2159262135
# 3      https://openalex.org/W2271608622
# 4      https://openalex.org/W2209115793
# ...                                 ...
# 11649  https://openalex.org/W4253285772
# 11650  https://openalex.org/W4253410054
# 11651  https://openalex.org/W4254963337
# 11652  https://openalex.org/W4255590455
# 11653  https://openalex.org/W4285411966
#
#                                                      doi  \
# 0                        https://doi.org/10.1071/is15033
# 1                        https://doi.org/10.1071/is13002
# 2                        https://doi.org/10.1071/is13030
# 3                        https://doi.org/10.1071/is15023
# 4                        https://doi.org/10.1071/is14019
# ...                                                  ...
# 11649  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 11650   https://doi.org/10.21684/0132-8077-2021-29-1-3-9
# 11651  https://doi.org/10.21684/0132-8077-2019-27-2-2...
# 11652  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 11653  https://doi.org/10.21684/0132-8077-2022-30-1-9...
#
#                                                    title  \
# 0      Integrative systematic studies on tardigrades ...
# 1      Morphological and molecular insights on Megalo...
# 2      Two distinct evolutionary lineages of the Asta...
# 3      Molecular evidence for non-monophyly of the pi...
# 4      Mitochondrial DNA analyses reveal widespread t...
# ...                                                  ...
# 11649  MERISTACARUS BOCHKOVI (ACARI, ORIBATIDA, LOHMA...
# 11650  TAXONOMIC CONTRIBUTION TO THE KNOWLEDGE OF THE...
# 11651  A NEW SYRINGOPHILID MITE (ACARIFORMES: SYRINGO...
# 11652  HYPOZETES ANDREII (ACARI, ORIBATIDA, TEGORIBAT...
# 11653  A new replacement name in Rhagidiidae (Acarifo...
#
#                                             display_name  publication_year  \
# 0      Integrative systematic studies on tardigrades ...              2016
# 1      Morphological and molecular insights on Megalo...              2013
# 2      Two distinct evolutionary lineages of the Asta...              2014
# 3      Molecular evidence for non-monophyly of the pi...              2016
# 4      Mitochondrial DNA analyses reveal widespread t...              2015
# ...                                                  ...               ...
# 11649  MERISTACARUS BOCHKOVI (ACARI, ORIBATIDA, LOHMA...              2019
# 11650  TAXONOMIC CONTRIBUTION TO THE KNOWLEDGE OF THE...              2021
# 11651  A NEW SYRINGOPHILID MITE (ACARIFORMES: SYRINGO...              2019
# 11652  HYPOZETES ANDREII (ACARI, ORIBATIDA, TEGORIBAT...              2019
# 11653  A new replacement name in Rhagidiidae (Acarifo...              2022
#
#       publication_date                                                ids  \
# 0           2016-08-31  {'openalex': 'https://openalex.org/W2282635459...
# 1           2013-01-01  {'openalex': 'https://openalex.org/W1534942643...
# 2           2014-01-01  {'openalex': 'https://openalex.org/W2159262135...
# 3           2016-01-01  {'openalex': 'https://openalex.org/W2271608622...
# 4           2015-01-01  {'openalex': 'https://openalex.org/W2209115793...
# ...                ...                                                ...
# 11649       2019-12-30  {'openalex': 'https://openalex.org/W4253285772...
# 11650       2021-01-01  {'openalex': 'https://openalex.org/W4253410054...
# 11651       2019-12-30  {'openalex': 'https://openalex.org/W4254963337...
# 11652       2019-12-30  {'openalex': 'https://openalex.org/W4255590455...
# 11653       2022-01-01  {'openalex': 'https://openalex.org/W4285411966...
#
#       language                                   primary_location  \
# 0           en  {'is_oa': False, 'landing_page_url': 'https://...
# 1           en  {'is_oa': False, 'landing_page_url': 'https://...
# 2           en  {'is_oa': False, 'landing_page_url': 'https://...
# 3           en  {'is_oa': False, 'landing_page_url': 'https://...
# 4           en  {'is_oa': False, 'landing_page_url': 'https://...
# ...        ...                                                ...
# 11649       en  {'is_oa': False, 'landing_page_url': 'https://...
# 11650       en  {'is_oa': False, 'landing_page_url': 'https://...
# 11651       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 11652       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 11653       en  {'is_oa': True, 'landing_page_url': 'https://d...
#
#                   type  ...  \
# 0      journal-article  ...
# 1      journal-article  ...
# 2      journal-article  ...
# 3      journal-article  ...
# 4      journal-article  ...
# ...                ...  ...
# 11649  journal-article  ...
# 11650  journal-article  ...
# 11651  journal-article  ...
# 11652  journal-article  ...
# 11653  journal-article  ...
#
#                                                   grants  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 11649  [{'funder': 'https://openalex.org/F4320323641'...
# 11650                                                 []
# 11651                                                 []
# 11652  [{'funder': 'https://openalex.org/F4320321079'...
# 11653                                                 []
#
#                                         referenced_works  \
# 0      [https://openalex.org/W133481079, https://open...
# 1      [https://openalex.org/W19893924, https://opena...
# 2      [https://openalex.org/W247704383, https://open...
# 3      [https://openalex.org/W108157262, https://open...
# 4      [https://openalex.org/W800964941, https://open...
# ...                                                  ...
# 11649  [https://openalex.org/W2290344131, https://ope...
# 11650  [https://openalex.org/W652923663, https://open...
# 11651  [https://openalex.org/W562402537, https://open...
# 11652  [https://openalex.org/W2760483133, https://ope...
# 11653  [https://openalex.org/W2493802979, https://ope...
#
#                                            related_works  \
# 0      [https://openalex.org/W1816690434, https://ope...
# 1      [https://openalex.org/W1534942643, https://ope...
# 2      [https://openalex.org/W1985896783, https://ope...
# 3      [https://openalex.org/W2001794630, https://ope...
# 4      [https://openalex.org/W1556637991, https://ope...
# ...                                                  ...
# 11649  [https://openalex.org/W1160645582, https://ope...
# 11650  [https://openalex.org/W2000844831, https://ope...
# 11651  [https://openalex.org/W1567510525, https://ope...
# 11652  [https://openalex.org/W2000844831, https://ope...
# 11653  [https://openalex.org/W1974801965, https://ope...
#
#                                               ngrams_url  \
# 0      https://api.openalex.org/works/W2282635459/ngrams
# 1      https://api.openalex.org/works/W1534942643/ngrams
# 2      https://api.openalex.org/works/W2159262135/ngrams
# 3      https://api.openalex.org/works/W2271608622/ngrams
# 4      https://api.openalex.org/works/W2209115793/ngrams
# ...                                                  ...
# 11649  https://api.openalex.org/works/W4253285772/ngrams
# 11650  https://api.openalex.org/works/W4253410054/ngrams
# 11651  https://api.openalex.org/works/W4254963337/ngrams
# 11652  https://api.openalex.org/works/W4255590455/ngrams
# 11653  https://api.openalex.org/works/W4285411966/ngrams
#
#                                  abstract_inverted_index  \
# 0      {'Tardigrades': [0], 'represent': [1], 'one': ...
# 1      {'The': [0, 73, 92], 'genus': [1], 'Megalothor...
# 2      {'Narrow-clawed': [0], 'crayfish': [1, 13, 85]...
# 3      {'The': [0, 18, 285], 'crabs': [1, 305], 'of':...
# 4      {'Antarctica': [0, 26, 233], 'contains': [1], ...
# ...                                                  ...
# 11649  {'A': [0], 'new': [1], 'oribatid': [2], 'mite'...
# 11650  {'A': [0, 15], 'new': [1, 16], 'oribatid': [2]...
# 11651  {'A': [0], 'new': [1, 33], 'quill': [2], 'mite...
# 11652  {'A': [0], 'new': [1, 44], 'oribatid': [2], 'm...
# 11653  {'The': [0, 38], 'recently': [1], 'proposed': ...
#
#                                         cited_by_api_url  \
# 0      https://api.openalex.org/works?filter=cites:W2...
# 1      https://api.openalex.org/works?filter=cites:W1...
# 2      https://api.openalex.org/works?filter=cites:W2...
# 3      https://api.openalex.org/works?filter=cites:W2...
# 4      https://api.openalex.org/works?filter=cites:W2...
# ...                                                  ...
# 11649  https://api.openalex.org/works?filter=cites:W4...
# 11650  https://api.openalex.org/works?filter=cites:W4...
# 11651  https://api.openalex.org/works?filter=cites:W4...
# 11652  https://api.openalex.org/works?filter=cites:W4...
# 11653  https://api.openalex.org/works?filter=cites:W4...
#
#                                           counts_by_year  \
# 0      [{'year': 2023, 'cited_by_count': 1}, {'year':...
# 1      [{'year': 2023, 'cited_by_count': 4}, {'year':...
# 2      [{'year': 2023, 'cited_by_count': 2}, {'year':...
# 3      [{'year': 2023, 'cited_by_count': 1}, {'year':...
# 4      [{'year': 2023, 'cited_by_count': 2}, {'year':...
# ...                                                  ...
# 11649                                                 []
# 11650                                                 []
# 11651                                                 []
# 11652                                                 []
# 11653                                                 []
#
#                      updated_date  created_date is_authors_truncated
# 0      2023-05-29T00:22:56.109044    2016-06-24                  NaN
# 1      2023-06-10T05:55:09.259272    2016-06-24                  NaN
# 2      2023-06-07T02:46:48.359217    2016-06-24                  NaN
# 3      2023-06-09T01:19:20.151699    2016-06-24                  NaN
# 4      2023-06-08T13:47:31.428930    2016-06-24                  NaN
# ...                           ...           ...                  ...
# 11649  2023-05-24T14:50:19.997838    2022-05-12                  NaN
# 11650  2023-05-29T20:38:15.338954    2022-05-12                  NaN
# 11651  2023-05-29T02:07:22.218820    2022-05-12                  NaN
# 11652  2023-05-29T14:33:08.088537    2022-05-12                  NaN
# 11653  2023-05-31T13:57:44.169346    2022-07-14                  NaN
#
# [11654 rows x 34 columns]

# %%
filtered_eu_articles.to_pickle("./data/keyword_filtered_articles_EU27_with_taxonomy_concept_in_journal.pkl")
