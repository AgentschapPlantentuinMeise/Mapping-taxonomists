# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ## 1. Backbone

# %%
backbone = pd.read_csv("../../data/external/backbone/Taxon.tsv", sep="\t", on_bad_lines='skip')
backbone = backbone[backbone["taxonRank"]=="species"]
# drop species with no canonical name
backbone = backbone.dropna(subset="canonicalName").set_index("canonicalName")
# and no full taxonomic lineage to the family
#backbone = backbone.dropna(subset=['kingdom', 'phylum', 'class', 'order', 'family'])
backbone = backbone[['taxonomicStatus',
                     'kingdom', 'phylum', 'class', 'order']]

#backbone["numberOfAuthors"] = [0,]*len(backbone.index)
# Out:
# C:\Users\melanie\AppData\Local\Temp\ipykernel_4560\2590554409.py:1: DtypeWarning: Columns (9,10,16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   backbone = pd.read_csv("../../data/external/backbone/Taxon.tsv", sep="\t", on_bad_lines='skip')

# %% [markdown]
# ## 2. Author counts

# %%
# version with dictionary, faster
# get disambiguated, European authors of taxonomic articles
authors = pd.read_pickle("../../data/processed/european_authors_disambiguated_truncated.pkl")

# link the author's expertise to the taxonomic backbone
available_species = set(backbone.index)
species_authors = {}

for subjects in authors["species_subject"]:
    if len(subjects) != 0: 
        for species in subjects:
            if species in available_species:
                if species not in species_authors:
                    species_authors[species] =  1
                else:
                    species_authors[species] += 1

# %%
sp_authors_df = pd.DataFrame(species_authors.keys(), species_authors.values()).reset_index()
sp_authors_df.columns = ["nr_authors", "canonicalName"]
sp_authors_df.set_index("canonicalName")
# Out:
#                           nr_authors
# canonicalName
# Canis aureus                      24
# Passiflora kikiana                 2
# Passiflora pachyantha              2
# Passiflora killipiana              2
# Passiflora guazumaefolia           2
# ...                              ...
# Cercospora zeina                   1
# Fusarium pininemorale              1
# Ophiostoma ips                     1
# Terminalia chebula                 1
# Terminalia arjuna                  1
#
# [23710 rows x 1 columns]

# %%
backbone = backbone.merge(sp_authors_df, on="canonicalName", how="left")

# %% [markdown]
# ## 3. Demand counts

# %%
redlist = pd.read_csv("../../data/external/IUCN_eu_region_tax_research_needed/assessments.csv")
cwr = pd.read_excel("../../data/external/crop wild relatives europe.xlsx", skiprows=1)
horizon = pd.read_csv("../../data/external/invasive species on the horizon for Europe.csv", sep="\t")

# %%
# get canonical names
#redlist = redlist.rename(columns={"scientificName":"canonicalName"})
cwr["canonicalName"] = [" ".join(x.split()[:2]) for x in cwr["CROP WILD RELATIVE"]]
#horizon = horizon.rename(columns={"Species Name":"canonicalName"})

# %%
def count_species(backbone, species_list, countname):
    available_species = set(backbone["canonicalName"])
    species_count = {}

    for species in species_list:
        if species in available_species:
            if species not in species_count:
                species_count[species] =  1
            else:
                species_count[species] += 1
                
    count_df = pd.DataFrame(species_count.keys(), species_count.values()).reset_index()
    count_df.columns = [countname, "canonicalName"]
    count_df.set_index("canonicalName")
    
    backbone = backbone.merge(count_df, on="canonicalName", how="left")
    return backbone

# %%
horizon
# Out:
#       taxonKey                                     scientificName  \
# 0      2768817                         Asparagus tenuifolius Lam.
# 1      2874569                                 Cucumis sativus L.
# 2      2930755                            Solanum triquetrum Cav.
# 3      2975139  Vicia narbonensis var. aegyptiaca Asch. & Schw...
# 4      2975196                           Vicia cappadocica Boiss.
# ...        ...                                                ...
# 3702   5373507                              Crambe fruticosa L.f.
# 3703   5567951                              Beta macrocarpa Guss.
# 3704   7227623                  Allium senescens subsp. senescens
# 3705   7262390               Ficus crassiramea subsp. crassiramea
# 3706   7605888  Elymus tsukushiensis var. transiens (Hack.) T....
#
#       acceptedTaxonKey                             acceptedScientificName  \
# 0              2768817                         Asparagus tenuifolius Lam.
# 1              2874569                                 Cucumis sativus L.
# 2              2930755                            Solanum triquetrum Cav.
# 3              2975139  Vicia narbonensis var. aegyptiaca Asch. & Schw...
# 4              2975196                           Vicia cappadocica Boiss.
# ...                ...                                                ...
# 3702           5373507                              Crambe fruticosa L.f.
# 3703           5567951                              Beta macrocarpa Guss.
# 3704           7227623                  Allium senescens subsp. senescens
# 3705           7262390               Ficus crassiramea subsp. crassiramea
# 3706           7605888  Elymus tsukushiensis var. transiens (Hack.) T....
#
#       numberOfOccurrences   taxonRank taxonomicStatus  kingdom  kingdomKey  \
# 0                      17     SPECIES        ACCEPTED  Plantae           6
# 1                    2554     SPECIES        ACCEPTED  Plantae           6
# 2                       3     SPECIES        ACCEPTED  Plantae           6
# 3                      28     VARIETY        ACCEPTED  Plantae           6
# 4                      34     SPECIES        ACCEPTED  Plantae           6
# ...                   ...         ...             ...      ...         ...
# 3702                    8     SPECIES        ACCEPTED  Plantae           6
# 3703                  572     SPECIES        ACCEPTED  Plantae           6
# 3704                    2  SUBSPECIES        ACCEPTED  Plantae           6
# 3705                    1  SUBSPECIES        ACCEPTED  Plantae           6
# 3706                    1     VARIETY        ACCEPTED  Plantae           6
#
#             phylum  ...  classKey           order  orderKey          family  \
# 0     Tracheophyta  ...       196     Asparagales      1169    Asparagaceae
# 1     Tracheophyta  ...       220    Cucurbitales   7224005   Cucurbitaceae
# 2     Tracheophyta  ...       220       Solanales      1176      Solanaceae
# 3     Tracheophyta  ...       220         Fabales      1370        Fabaceae
# 4     Tracheophyta  ...       220         Fabales      1370        Fabaceae
# ...            ...  ...       ...             ...       ...             ...
# 3702  Tracheophyta  ...       220     Brassicales   7225535    Brassicaceae
# 3703  Tracheophyta  ...       220  Caryophyllales       422   Amaranthaceae
# 3704  Tracheophyta  ...       196     Asparagales      1169  Amaryllidaceae
# 3705  Tracheophyta  ...       220         Rosales       691        Moraceae
# 3706  Tracheophyta  ...       196          Poales      1369         Poaceae
#
#       familyKey      genus    genusKey                species  speciesKey  \
# 0          7683  Asparagus   9527393.0  Asparagus tenuifolius   2768817.0
# 1          6634    Cucumis   2874568.0        Cucumis sativus   2874569.0
# 2          7717    Solanum   2928997.0     Solanum triquetrum   2930755.0
# 3          5386      Vicia   2974751.0      Vicia narbonensis   2975132.0
# 4          5386      Vicia   2974751.0      Vicia cappadocica   2975196.0
# ...         ...        ...         ...                    ...         ...
# 3702       3112     Crambe   3041334.0       Crambe fruticosa   5373507.0
# 3703       3064       Beta   3083586.0        Beta macrocarpa   5567951.0
# 3704       7682     Allium   9624496.0       Allium senescens   2855719.0
# 3705       6640      Ficus   2984588.0      Ficus crassiramea   7262389.0
# 3706       3073     Elymus  10465436.0   Elymus tsukushiensis   5671702.0
#
#      iucnRedListCategory
# 0                     LC
# 1                     NE
# 2                     NE
# 3                    NaN
# 4                     NE
# ...                  ...
# 3702                  NT
# 3703                  NE
# 3704                 NaN
# 3705                 NaN
# 3706                 NaN
#
# [3707 rows x 22 columns]

# %%
backbone = count_species(backbone, redlist["scientificName"], "taxonomicResearchNeeded")
backbone = count_species(backbone, cwr["canonicalName"], "cropWildRelatives")
backbone = count_species(backbone, horizon["species"], "horizonInvasives")

backbone
# Out:
#                        canonicalName    taxonomicStatus    kingdom  \
# 0        Veronicastrum lungtsuanense            synonym    Plantae
# 1                 Thysananthus minor           accepted    Plantae
# 2                   Erigone cristata  homotypic synonym   Animalia
# 3                  Ahomana chilensis           accepted   Animalia
# 4             Costatoverruca baxteri           accepted   Animalia
# ...                              ...                ...        ...
# 4976831           Pottia paraguensis            synonym    Plantae
# 4976832       Lestodiplosis polypori            synonym   Animalia
# 4976833              Stictia gravida            synonym   Animalia
# 4976834          Epialtoides hiltoni           accepted   Animalia
# 4976835           Ceratium pennnatum            synonym  Chromista
#
#                   phylum              class           order  nr_authors  \
# 0           Tracheophyta      Magnoliopsida        Lamiales         NaN
# 1        Marchantiophyta  Jungermanniopsida      Porellales         NaN
# 2             Arthropoda            Insecta         Diptera         NaN
# 3             Arthropoda            Insecta       Hemiptera         NaN
# 4             Arthropoda        Maxillopoda        Sessilia         NaN
# ...                  ...                ...             ...         ...
# 4976831        Bryophyta          Bryopsida  Orthotrichales         NaN
# 4976832       Arthropoda            Insecta         Diptera         NaN
# 4976833       Arthropoda            Insecta     Hymenoptera         NaN
# 4976834       Arthropoda       Malacostraca        Decapoda         NaN
# 4976835          Myzozoa        Dinophyceae   Gonyaulacales         NaN
#
#          taxonomicResearchNeeded_x  cropWildRelatives_x  \
# 0                              NaN                  NaN
# 1                              NaN                  NaN
# 2                              NaN                  NaN
# 3                              NaN                  NaN
# 4                              NaN                  NaN
# ...                            ...                  ...
# 4976831                        NaN                  NaN
# 4976832                        NaN                  NaN
# 4976833                        NaN                  NaN
# 4976834                        NaN                  NaN
# 4976835                        NaN                  NaN
#
#          taxonomicResearchNeeded_y  cropWildRelatives_y  horizonInvasives
# 0                              NaN                  NaN               NaN
# 1                              NaN                  NaN               NaN
# 2                              NaN                  NaN               NaN
# 3                              NaN                  NaN               NaN
# 4                              NaN                  NaN               NaN
# ...                            ...                  ...               ...
# 4976831                        NaN                  NaN               NaN
# 4976832                        NaN                  NaN               NaN
# 4976833                        NaN                  NaN               NaN
# 4976834                        NaN                  NaN               NaN
# 4976835                        NaN                  NaN               NaN
#
# [4976836 rows x 12 columns]

# %%
set(list(backbone["horizonInvasives"]))

# %% [markdown]
# ## 4. Count on order level

# %%
order = backbone[["kingdom", "phylum", "class", "order"]]
order = order[order["kingdom"]!="Bacteria"]
order = order[order["kingdom"]!="Archaea"].drop_duplicates(ignore_index=True)
order["nr_authors"] = [0.0,]*len(order)
order

# %%
for row in backbone[backbone["nr_authors"]==backbone["nr_authors"]].itertuples():
    order.loc[order["order"]==row.order,"nr_authors"] += row.nr_authors

# %%
order["taxonomicResearchNeeded"] = [0.0,]*len(order)
for row in backbone[backbone["taxonomicResearchNeeded"]==backbone["taxonomicResearchNeeded"]].itertuples():
    order.loc[order["order"]==row.order,"taxonomicResearchNeeded"] += row.taxonomicResearchNeeded

# %%
order["cropWildRelatives"] = [0.0,]*len(order)
for row in backbone[backbone["cropWildRelatives"]==backbone["cropWildRelatives"]].itertuples():
    order.loc[order["order"]==row.order,"cropWildRelatives"] += row.cropWildRelatives

# %%
order["horizonInvasives"] = [0.0,]*len(order)
for row in backbone[backbone["horizonInvasives"]==backbone["horizonInvasives"]].itertuples():
    order.loc[order["order"]==row.order,"horizonInvasives"] += row.horizonInvasives

# %%
order

# %%
order.to_pickle("../../data/processed/supply_and_demand_order_level.pkl")
order.to_csv("../../data/processed/supply_and_demand_order_level.tsv", sep="\t")
