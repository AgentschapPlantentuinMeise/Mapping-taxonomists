# %% [markdown]
# # 1. Using OpenAlex to find taxonomists
#
# ## 1.2. Preprocessing OpenAlex article data into author data
#
# Previously, we found a list of articles of taxonomic interest. Ultimately, we are interested in the authors, whom we assume are taxonomists or at least have relevant expertise about the taxon studied in the paper. We extract the information of the authors from the OpenAlex article data here.

# %%
import pandas as pd
import matplotlib.pyplot as plt # version 3.5.2
import pickle
import openalex

# %%
eu_tax_articles = pd.read_pickle("./data/keyword_filtered_articles_EU27_with_taxonomy_concept_in_journal.pkl")
eu_tax_articles = openalex.flatten_works(eu_tax_articles)
eu_tax_articles
# Out:
#                                      id  \
# 0      https://openalex.org/W2282635459
# 1      https://openalex.org/W1534942643
# 2      https://openalex.org/W2159262135
# 3      https://openalex.org/W2271608622
# 4      https://openalex.org/W2209115793
# ...                                 ...
# 11649  https://openalex.org/W4253285772
# 11650  https://openalex.org/W4253410054
# 11651  https://openalex.org/W4254963337
# 11652  https://openalex.org/W4255590455
# 11653  https://openalex.org/W4285411966
#
#                                                      doi  \
# 0                        https://doi.org/10.1071/is15033
# 1                        https://doi.org/10.1071/is13002
# 2                        https://doi.org/10.1071/is13030
# 3                        https://doi.org/10.1071/is15023
# 4                        https://doi.org/10.1071/is14019
# ...                                                  ...
# 11649  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 11650   https://doi.org/10.21684/0132-8077-2021-29-1-3-9
# 11651  https://doi.org/10.21684/0132-8077-2019-27-2-2...
# 11652  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 11653  https://doi.org/10.21684/0132-8077-2022-30-1-9...
#
#                                                    title  \
# 0      Integrative systematic studies on tardigrades ...
# 1      Morphological and molecular insights on Megalo...
# 2      Two distinct evolutionary lineages of the Asta...
# 3      Molecular evidence for non-monophyly of the pi...
# 4      Mitochondrial DNA analyses reveal widespread t...
# ...                                                  ...
# 11649  MERISTACARUS BOCHKOVI (ACARI, ORIBATIDA, LOHMA...
# 11650  TAXONOMIC CONTRIBUTION TO THE KNOWLEDGE OF THE...
# 11651  A NEW SYRINGOPHILID MITE (ACARIFORMES: SYRINGO...
# 11652  HYPOZETES ANDREII (ACARI, ORIBATIDA, TEGORIBAT...
# 11653  A new replacement name in Rhagidiidae (Acarifo...
#
#                                             display_name  publication_year  \
# 0      Integrative systematic studies on tardigrades ...              2016
# 1      Morphological and molecular insights on Megalo...              2013
# 2      Two distinct evolutionary lineages of the Asta...              2014
# 3      Molecular evidence for non-monophyly of the pi...              2016
# 4      Mitochondrial DNA analyses reveal widespread t...              2015
# ...                                                  ...               ...
# 11649  MERISTACARUS BOCHKOVI (ACARI, ORIBATIDA, LOHMA...              2019
# 11650  TAXONOMIC CONTRIBUTION TO THE KNOWLEDGE OF THE...              2021
# 11651  A NEW SYRINGOPHILID MITE (ACARIFORMES: SYRINGO...              2019
# 11652  HYPOZETES ANDREII (ACARI, ORIBATIDA, TEGORIBAT...              2019
# 11653  A new replacement name in Rhagidiidae (Acarifo...              2022
#
#       publication_date                                                ids  \
# 0           2016-08-31  {'openalex': 'https://openalex.org/W2282635459...
# 1           2013-01-01  {'openalex': 'https://openalex.org/W1534942643...
# 2           2014-01-01  {'openalex': 'https://openalex.org/W2159262135...
# 3           2016-01-01  {'openalex': 'https://openalex.org/W2271608622...
# 4           2015-01-01  {'openalex': 'https://openalex.org/W2209115793...
# ...                ...                                                ...
# 11649       2019-12-30  {'openalex': 'https://openalex.org/W4253285772...
# 11650       2021-01-01  {'openalex': 'https://openalex.org/W4253410054...
# 11651       2019-12-30  {'openalex': 'https://openalex.org/W4254963337...
# 11652       2019-12-30  {'openalex': 'https://openalex.org/W4255590455...
# 11653       2022-01-01  {'openalex': 'https://openalex.org/W4285411966...
#
#       language                                   primary_location  \
# 0           en  {'is_oa': False, 'landing_page_url': 'https://...
# 1           en  {'is_oa': False, 'landing_page_url': 'https://...
# 2           en  {'is_oa': False, 'landing_page_url': 'https://...
# 3           en  {'is_oa': False, 'landing_page_url': 'https://...
# 4           en  {'is_oa': False, 'landing_page_url': 'https://...
# ...        ...                                                ...
# 11649       en  {'is_oa': False, 'landing_page_url': 'https://...
# 11650       en  {'is_oa': False, 'landing_page_url': 'https://...
# 11651       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 11652       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 11653       en  {'is_oa': True, 'landing_page_url': 'https://d...
#
#                   type  ...           source_issn  \
# 0      journal-article  ...  1447-2600\n1445-5226
# 1      journal-article  ...  1447-2600\n1445-5226
# 2      journal-article  ...  1447-2600\n1445-5226
# 3      journal-article  ...  1447-2600\n1445-5226
# 4      journal-article  ...  1447-2600\n1445-5226
# ...                ...  ...                   ...
# 11649  journal-article  ...  2221-5115\n0132-8077
# 11650  journal-article  ...  2221-5115\n0132-8077
# 11651  journal-article  ...  2221-5115\n0132-8077
# 11652  journal-article  ...  2221-5115\n0132-8077
# 11653  journal-article  ...  2221-5115\n0132-8077
#
#                source_host_organization source_host_organization_name  \
# 0      https://openalex.org/P4310320302              CSIRO Publishing
# 1      https://openalex.org/P4310320302              CSIRO Publishing
# 2      https://openalex.org/P4310320302              CSIRO Publishing
# 3      https://openalex.org/P4310320302              CSIRO Publishing
# 4      https://openalex.org/P4310320302              CSIRO Publishing
# ...                                 ...                           ...
# 11649  https://openalex.org/P4310312765          University of Tyumen
# 11650  https://openalex.org/P4310312765          University of Tyumen
# 11651  https://openalex.org/P4310312765          University of Tyumen
# 11652  https://openalex.org/P4310312765          University of Tyumen
# 11653  https://openalex.org/P4310312765          University of Tyumen
#
#          source_host_organization_lineage  \
# 0      [https://openalex.org/P4310320302]
# 1      [https://openalex.org/P4310320302]
# 2      [https://openalex.org/P4310320302]
# 3      [https://openalex.org/P4310320302]
# 4      [https://openalex.org/P4310320302]
# ...                                   ...
# 11649  [https://openalex.org/P4310312765]
# 11650  [https://openalex.org/P4310312765]
# 11651  [https://openalex.org/P4310312765]
# 11652  [https://openalex.org/P4310312765]
# 11653  [https://openalex.org/P4310312765]
#
#       source_host_organization_lineage_names  source_type  is_oa  oa_status  \
# 0                         [CSIRO Publishing]      journal   True      green
# 1                         [CSIRO Publishing]      journal  False     closed
# 2                         [CSIRO Publishing]      journal  False     closed
# 3                         [CSIRO Publishing]      journal  False     closed
# 4                         [CSIRO Publishing]      journal   True      green
# ...                                      ...          ...    ...        ...
# 11649                 [University of Tyumen]      journal  False     closed
# 11650                 [University of Tyumen]      journal  False     closed
# 11651                 [University of Tyumen]      journal   True     bronze
# 11652                 [University of Tyumen]      journal   True     bronze
# 11653                 [University of Tyumen]      journal   True     bronze
#
#                                                   oa_url  \
# 0      https://iris.unimore.it/bitstream/11380/110720...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      https://oa.upm.es/40973/1/INVE_MEM_2015_224830...
# ...                                                  ...
# 11649                                               None
# 11650                                               None
# 11651  https://doi.org/10.21684/0132-8077-2019-27-2-2...
# 11652  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 11653  https://doi.org/10.21684/0132-8077-2022-30-1-9...
#
#       any_repository_has_fulltext
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                            True
# ...                           ...
# 11649                       False
# 11650                       False
# 11651                       False
# 11652                        True
# 11653                       False
#
# [11654 rows x 53 columns]

# %%
eu_tax_articles.loc[0]
# Out:
# id                                                         https://openalex.org/W2282635459
# doi                                                         https://doi.org/10.1071/is15033
# title                                     Integrative systematic studies on tardigrades ...
# display_name                              Integrative systematic studies on tardigrades ...
# publication_year                                                                       2016
# publication_date                                                                 2016-08-31
# ids                                       {'openalex': 'https://openalex.org/W2282635459...
# language                                                                                 en
# primary_location                          {'is_oa': False, 'landing_page_url': 'https://...
# type                                                                        journal-article
# open_access                               {'is_oa': True, 'oa_status': 'green', 'oa_url'...
# authorships                               [{'author_position': 'first', 'author': {'id':...
# corresponding_author_ids                                                                 []
# corresponding_institution_ids                                                            []
# apc_payment                                                                            None
# cited_by_count                                                                           53
# biblio                                    {'volume': '30', 'issue': '4', 'first_page': '...
# is_retracted                                                                          False
# is_paratext                                                                           False
# concepts                                  [{'id': 'https://openalex.org/C2777895711', 'w...
# mesh                                                                                     []
# locations_count                                                                           2
# locations                                 [{'is_oa': False, 'landing_page_url': 'https:/...
# best_oa_location                          {'is_oa': True, 'landing_page_url': 'http://hd...
# grants                                                                                   []
# referenced_works                          [https://openalex.org/W133481079, https://open...
# related_works                             [https://openalex.org/W1816690434, https://ope...
# ngrams_url                                https://api.openalex.org/works/W2282635459/ngrams
# abstract_inverted_index                   {'Tardigrades': [0], 'represent': [1], 'one': ...
# cited_by_api_url                          https://api.openalex.org/works?filter=cites:W2...
# counts_by_year                            [{'year': 2023, 'cited_by_count': 1}, {'year':...
# updated_date                                                     2023-05-29T00:22:56.109044
# created_date                                                                     2016-06-24
# is_authors_truncated                                                                    NaN
# location_is_oa                                                                        False
# location_landing_page_url                                   https://doi.org/10.1071/is15033
# location_pdf_url                                                                       None
# location_source                           {'id': 'https://openalex.org/S190005928', 'dis...
# location_license                                                                       None
# location_version                                                                       None
# source_id                                                   https://openalex.org/S190005928
# source_display_name                                                Invertebrate Systematics
# source_issn_l                                                                     1445-5226
# source_issn                                                            1447-2600\n1445-5226
# source_host_organization                                   https://openalex.org/P4310320302
# source_host_organization_name                                              CSIRO Publishing
# source_host_organization_lineage                         [https://openalex.org/P4310320302]
# source_host_organization_lineage_names                                   [CSIRO Publishing]
# source_type                                                                         journal
# is_oa                                                                                  True
# oa_status                                                                             green
# oa_url                                    https://iris.unimore.it/bitstream/11380/110720...
# any_repository_has_fulltext                                                            True
# Name: 0, dtype: object

# %%
authors_eu_tax = openalex.get_authors(eu_tax_articles)
authors_eu_tax
# Out:
#                              article_id author_position  \
# 0      https://openalex.org/W2282635459           first
# 1      https://openalex.org/W2282635459          middle
# 2      https://openalex.org/W2282635459          middle
# 3      https://openalex.org/W2282635459          middle
# 4      https://openalex.org/W2282635459          middle
# ...                                 ...             ...
# 49494  https://openalex.org/W4255590455          middle
# 49495  https://openalex.org/W4255590455          middle
# 49496  https://openalex.org/W4255590455            last
# 49497  https://openalex.org/W4285411966           first
# 49498  https://openalex.org/W4285411966            last
#
#                               author_id        author_display_name  \
# 0      https://openalex.org/A2528062669              Matteo Vecchi
# 1      https://openalex.org/A2143576881             Michele Cesari
# 2      https://openalex.org/A4360091361          Roberto Bertolani
# 3      https://openalex.org/A4335463764         K. Ingemar Jönsson
# 4      https://openalex.org/A2077559806            Lorena Rebecchi
# ...                                 ...                        ...
# 49494  https://openalex.org/A4334142574  Elizabeth A. Hugo-Coetzee
# 49495  https://openalex.org/A4353913507      Alexander A. Khaustov
# 49496  https://openalex.org/A4355237428             Jenő Kontschán
# 49497  https://openalex.org/A4300730993           Fabio Cianferoni
# 49498  https://openalex.org/A4300730994          Filippo Ceccolini
#
#                                        orcid  \
# 0      https://orcid.org/0000-0002-7995-6827
# 1      https://orcid.org/0000-0001-8857-3791
# 2                                       None
# 3                                       None
# 4      https://orcid.org/0000-0002-0702-1846
# ...                                      ...
# 49494                                   None
# 49495                                   None
# 49496                                   None
# 49497                                   None
# 49498                                   None
#
#                                   raw_affiliation_string  \
# 0      Department of Life Sciences University of Mode...
# 1      Department of Life Sciences University of Mode...
# 2      Department of Life Sciences University of Mode...
# 3      School of Education and Environment, Kristians...
# 4      Department of Life Sciences University of Mode...
# ...                                                  ...
# 49494  National Museum, Bloemfontein, South Africa; U...
# 49495  X-BIO Institute, Tyumen State University, Tyum...
# 49496  Plant Protection Institute, Centre for Agricul...
# 49497           National Research Council of Italy (CNR)
# 49498                             University of Florence
#
#                                 inst_id  \
# 0       https://openalex.org/I122346577
# 1       https://openalex.org/I122346577
# 2       https://openalex.org/I122346577
# 3       https://openalex.org/I193278943
# 4       https://openalex.org/I122346577
# ...                                 ...
# 49494  https://openalex.org/I4210088520
# 49495  https://openalex.org/I3020440027
# 49496  https://openalex.org/I4210156273
# 49497  https://openalex.org/I4210155236
# 49498    https://openalex.org/I45084792
#
#                             inst_display_name                        ror  \
# 0      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02
# 1      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02
# 2      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02
# 3                     Kristianstad University  https://ror.org/00tkrft03
# 4      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02
# ...                                       ...                        ...
# 49494                         National Museum  https://ror.org/004qfqh71
# 49495                    University of Tyumen  https://ror.org/05vehv290
# 49496              Plant Protection Institute  https://ror.org/052t9a145
# 49497               National Research Council  https://ror.org/04zaypm56
# 49498                  University of Florence  https://ror.org/04jr1s763
#
#       inst_country_code  ...           source_issn  \
# 0                    IT  ...  1447-2600\n1445-5226
# 1                    IT  ...  1447-2600\n1445-5226
# 2                    IT  ...  1447-2600\n1445-5226
# 3                    SE  ...  1447-2600\n1445-5226
# 4                    IT  ...  1447-2600\n1445-5226
# ...                 ...  ...                   ...
# 49494                ZA  ...  2221-5115\n0132-8077
# 49495                RU  ...  2221-5115\n0132-8077
# 49496                HU  ...  2221-5115\n0132-8077
# 49497                IT  ...  2221-5115\n0132-8077
# 49498                IT  ...  2221-5115\n0132-8077
#
#                source_host_organization source_host_organization_name  \
# 0      https://openalex.org/P4310320302              CSIRO Publishing
# 1      https://openalex.org/P4310320302              CSIRO Publishing
# 2      https://openalex.org/P4310320302              CSIRO Publishing
# 3      https://openalex.org/P4310320302              CSIRO Publishing
# 4      https://openalex.org/P4310320302              CSIRO Publishing
# ...                                 ...                           ...
# 49494  https://openalex.org/P4310312765          University of Tyumen
# 49495  https://openalex.org/P4310312765          University of Tyumen
# 49496  https://openalex.org/P4310312765          University of Tyumen
# 49497  https://openalex.org/P4310312765          University of Tyumen
# 49498  https://openalex.org/P4310312765          University of Tyumen
#
#          source_host_organization_lineage  \
# 0      [https://openalex.org/P4310320302]
# 1      [https://openalex.org/P4310320302]
# 2      [https://openalex.org/P4310320302]
# 3      [https://openalex.org/P4310320302]
# 4      [https://openalex.org/P4310320302]
# ...                                   ...
# 49494  [https://openalex.org/P4310312765]
# 49495  [https://openalex.org/P4310312765]
# 49496  [https://openalex.org/P4310312765]
# 49497  [https://openalex.org/P4310312765]
# 49498  [https://openalex.org/P4310312765]
#
#       source_host_organization_lineage_names  source_type is_oa oa_status  \
# 0                         [CSIRO Publishing]      journal  True     green
# 1                         [CSIRO Publishing]      journal  True     green
# 2                         [CSIRO Publishing]      journal  True     green
# 3                         [CSIRO Publishing]      journal  True     green
# 4                         [CSIRO Publishing]      journal  True     green
# ...                                      ...          ...   ...       ...
# 49494                 [University of Tyumen]      journal  True    bronze
# 49495                 [University of Tyumen]      journal  True    bronze
# 49496                 [University of Tyumen]      journal  True    bronze
# 49497                 [University of Tyumen]      journal  True    bronze
# 49498                 [University of Tyumen]      journal  True    bronze
#
#                                                   oa_url  \
# 0      https://iris.unimore.it/bitstream/11380/110720...
# 1      https://iris.unimore.it/bitstream/11380/110720...
# 2      https://iris.unimore.it/bitstream/11380/110720...
# 3      https://iris.unimore.it/bitstream/11380/110720...
# 4      https://iris.unimore.it/bitstream/11380/110720...
# ...                                                  ...
# 49494  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 49495  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 49496  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 49497  https://doi.org/10.21684/0132-8077-2022-30-1-9...
# 49498  https://doi.org/10.21684/0132-8077-2022-30-1-9...
#
#       any_repository_has_fulltext
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# ...                           ...
# 49494                        True
# 49495                        True
# 49496                        True
# 49497                       False
# 49498                       False
#
# [49499 rows x 64 columns]

# %%
only_eu_authors = openalex.get_eu_authors(authors_eu_tax)
only_eu_authors
# Out:
#        Index                        article_id author_position  \
# 0          0  https://openalex.org/W2282635459           first
# 1          1  https://openalex.org/W2282635459          middle
# 2          2  https://openalex.org/W2282635459          middle
# 3          3  https://openalex.org/W2282635459          middle
# 4          4  https://openalex.org/W2282635459          middle
# ...      ...                               ...             ...
# 25098  49489  https://openalex.org/W4253410054            last
# 25099  49490  https://openalex.org/W4254963337           first
# 25100  49496  https://openalex.org/W4255590455            last
# 25101  49497  https://openalex.org/W4285411966           first
# 25102  49498  https://openalex.org/W4285411966            last
#
#                               author_id author_display_name  \
# 0      https://openalex.org/A2528062669       Matteo Vecchi
# 1      https://openalex.org/A2143576881      Michele Cesari
# 2      https://openalex.org/A4360091361   Roberto Bertolani
# 3      https://openalex.org/A4335463764  K. Ingemar Jönsson
# 4      https://openalex.org/A2077559806     Lorena Rebecchi
# ...                                 ...                 ...
# 25098  https://openalex.org/A2118604301         Josef Starý
# 25099  https://openalex.org/A4357507713     Maciej Skoracki
# 25100  https://openalex.org/A4355237428      Jenő Kontschán
# 25101  https://openalex.org/A4300730993    Fabio Cianferoni
# 25102  https://openalex.org/A4300730994   Filippo Ceccolini
#
#                                        orcid  \
# 0      https://orcid.org/0000-0002-7995-6827
# 1      https://orcid.org/0000-0001-8857-3791
# 2                                       None
# 3                                       None
# 4      https://orcid.org/0000-0002-0702-1846
# ...                                      ...
# 25098  https://orcid.org/0000-0002-9440-4254
# 25099                                   None
# 25100                                   None
# 25101                                   None
# 25102                                   None
#
#                                   raw_affiliation_string  \
# 0      Department of Life Sciences University of Mode...
# 1      Department of Life Sciences University of Mode...
# 2      Department of Life Sciences University of Mode...
# 3      School of Education and Environment, Kristians...
# 4      Department of Life Sciences University of Mode...
# ...                                                  ...
# 25098                          Institute of Soil Biology
# 25099  Department of Animal Morphology, Adam Mickiewi...
# 25100  Plant Protection Institute, Centre for Agricul...
# 25101           National Research Council of Italy (CNR)
# 25102                             University of Florence
#
#                                 inst_id  \
# 0       https://openalex.org/I122346577
# 1       https://openalex.org/I122346577
# 2       https://openalex.org/I122346577
# 3       https://openalex.org/I193278943
# 4       https://openalex.org/I122346577
# ...                                 ...
# 25098  https://openalex.org/I4210124224
# 25099   https://openalex.org/I173161963
# 25100  https://openalex.org/I4210156273
# 25101  https://openalex.org/I4210155236
# 25102    https://openalex.org/I45084792
#
#                             inst_display_name                        ror  ...  \
# 0      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02  ...
# 1      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02  ...
# 2      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02  ...
# 3                     Kristianstad University  https://ror.org/00tkrft03  ...
# 4      University of Modena and Reggio Emilia  https://ror.org/02d4c4y02  ...
# ...                                       ...                        ...  ...
# 25098               Institute of Soil Biology  https://ror.org/02tz8r820  ...
# 25099                    University of Prešov  https://ror.org/02ndfsn03  ...
# 25100              Plant Protection Institute  https://ror.org/052t9a145  ...
# 25101               National Research Council  https://ror.org/04zaypm56  ...
# 25102                  University of Florence  https://ror.org/04jr1s763  ...
#
#                 source_issn          source_host_organization  \
# 0      1447-2600\n1445-5226  https://openalex.org/P4310320302
# 1      1447-2600\n1445-5226  https://openalex.org/P4310320302
# 2      1447-2600\n1445-5226  https://openalex.org/P4310320302
# 3      1447-2600\n1445-5226  https://openalex.org/P4310320302
# 4      1447-2600\n1445-5226  https://openalex.org/P4310320302
# ...                     ...                               ...
# 25098  2221-5115\n0132-8077  https://openalex.org/P4310312765
# 25099  2221-5115\n0132-8077  https://openalex.org/P4310312765
# 25100  2221-5115\n0132-8077  https://openalex.org/P4310312765
# 25101  2221-5115\n0132-8077  https://openalex.org/P4310312765
# 25102  2221-5115\n0132-8077  https://openalex.org/P4310312765
#
#       source_host_organization_name    source_host_organization_lineage  \
# 0                  CSIRO Publishing  [https://openalex.org/P4310320302]
# 1                  CSIRO Publishing  [https://openalex.org/P4310320302]
# 2                  CSIRO Publishing  [https://openalex.org/P4310320302]
# 3                  CSIRO Publishing  [https://openalex.org/P4310320302]
# 4                  CSIRO Publishing  [https://openalex.org/P4310320302]
# ...                             ...                                 ...
# 25098          University of Tyumen  [https://openalex.org/P4310312765]
# 25099          University of Tyumen  [https://openalex.org/P4310312765]
# 25100          University of Tyumen  [https://openalex.org/P4310312765]
# 25101          University of Tyumen  [https://openalex.org/P4310312765]
# 25102          University of Tyumen  [https://openalex.org/P4310312765]
#
#       source_host_organization_lineage_names source_type  is_oa oa_status  \
# 0                         [CSIRO Publishing]     journal   True     green
# 1                         [CSIRO Publishing]     journal   True     green
# 2                         [CSIRO Publishing]     journal   True     green
# 3                         [CSIRO Publishing]     journal   True     green
# 4                         [CSIRO Publishing]     journal   True     green
# ...                                      ...         ...    ...       ...
# 25098                 [University of Tyumen]     journal  False    closed
# 25099                 [University of Tyumen]     journal   True    bronze
# 25100                 [University of Tyumen]     journal   True    bronze
# 25101                 [University of Tyumen]     journal   True    bronze
# 25102                 [University of Tyumen]     journal   True    bronze
#
#                                                   oa_url  \
# 0      https://iris.unimore.it/bitstream/11380/110720...
# 1      https://iris.unimore.it/bitstream/11380/110720...
# 2      https://iris.unimore.it/bitstream/11380/110720...
# 3      https://iris.unimore.it/bitstream/11380/110720...
# 4      https://iris.unimore.it/bitstream/11380/110720...
# ...                                                  ...
# 25098                                               None
# 25099  https://doi.org/10.21684/0132-8077-2019-27-2-2...
# 25100  https://doi.org/10.21684/0132-8077-2019-27-2-1...
# 25101  https://doi.org/10.21684/0132-8077-2022-30-1-9...
# 25102  https://doi.org/10.21684/0132-8077-2022-30-1-9...
#
#       any_repository_has_fulltext
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
# ...                           ...
# 25098                       False
# 25099                       False
# 25100                        True
# 25101                       False
# 25102                       False
#
# [25103 rows x 65 columns]

# %%
single_eu_authors = openalex.get_single_authors(only_eu_authors).reset_index(drop=True)
single_eu_authors
# Out:
#        Index                        article_id author_position  \
# 0      39349  https://openalex.org/W4286715885           first
# 1      11446  https://openalex.org/W4282829982            last
# 2      10509  https://openalex.org/W3191918968          middle
# 3      13969  https://openalex.org/W2949939566          middle
# 4      15848  https://openalex.org/W2944966715            last
# ...      ...                               ...             ...
# 10470  25993   https://openalex.org/W336386924           first
# 10471  40808  https://openalex.org/W3173396053           first
# 10472  32820  https://openalex.org/W3209978301          middle
# 10473  16561  https://openalex.org/W1982107118          middle
# 10474  18650  https://openalex.org/W4220821500          middle
#
#                               author_id         author_display_name  \
# 0      https://openalex.org/A2666249949         Yasmina Marin-Felix
# 1      https://openalex.org/A2105432390              Marcus Lehnert
# 2      https://openalex.org/A2095303932            Katharina Zacher
# 3      https://openalex.org/A2791682482                Paul van Els
# 4      https://openalex.org/A4374495681                Nina Rønsted
# ...                                 ...                         ...
# 10470  https://openalex.org/A2645630823      Mariana Y. Deli Antoni
# 10471  https://openalex.org/A4356957360  Pedro Pablo Ferrer Gallego
# 10472  https://openalex.org/A4349394943             Frédéric Chérot
# 10473   https://openalex.org/A390288074           Vladimír Vrkoslav
# 10474  https://openalex.org/A4353946531              Marco Leonardi
#
#                                        orcid  \
# 0                                       None
# 1      https://orcid.org/0000-0002-7202-7734
# 2      https://orcid.org/0000-0001-8897-1255
# 3      https://orcid.org/0000-0002-9499-8873
# 4                                       None
# ...                                      ...
# 10470                                   None
# 10471                                   None
# 10472                                   None
# 10473  https://orcid.org/0000-0002-5126-8360
# 10474                                   None
#
#                                   raw_affiliation_string  \
# 0      Helmholtz Centre for Infection Research; Techn...
# 1      Martin-Luther-Universität Halle-Wittenberg, Be...
# 2      Alfred Wegener Institute Helmholtz Centre for ...
# 3      Groningen Institute for Evolutionary Life Scie...
# 4      Natural History Museum of Denmark, University ...
# ...                                                  ...
# 10470
# 10471  Servicio de Vida Silvestre, Centro para la Inv...
# 10472  Département de l’Etude du Milieu Naturel et Ag...
# 10473  Institute of Organic Chemistry and Biochemistr...
# 10474  Sect. Environmental Sciences, Dept. MeSVA, Uni...
#
#                                 inst_id  \
# 0      https://openalex.org/I4210124929
# 1        https://openalex.org/I68956291
# 2       https://openalex.org/I127251866
# 3       https://openalex.org/I169381384
# 4      https://openalex.org/I4210110903
# ...                                 ...
# 10470   https://openalex.org/I134820265
# 10471  https://openalex.org/I2802828525
# 10472  https://openalex.org/I4210113172
# 10473  https://openalex.org/I4210145889
# 10474    https://openalex.org/I26415053
#
#                                        inst_display_name  \
# 0                Helmholtz Centre for Infection Research
# 1              Martin Luther University Halle-Wittenberg
# 2      Alfred Wegener Institute for Polar and Marine ...
# 3                                University of Groningen
# 4                          Natural History Museum Aarhus
# ...                                                  ...
# 10470                  Spanish National Research Council
# 10471                             Generalitat Valenciana
# 10472                         Service Public de Wallonie
# 10473  Czech Academy of Sciences, Institute of Organi...
# 10474                             University of L'Aquila
#
#                              ror  ...           source_issn  \
# 0      https://ror.org/03d0p2685  ...  1861-8952\n1617-416X
# 1      https://ror.org/05gqaka33  ...  1179-3163\n1179-3155
# 2      https://ror.org/032e6b942  ...  1179-3163\n1179-3155
# 3      https://ror.org/012p63287  ...  1076-836X\n1063-5157
# 4      https://ror.org/0166x0j30  ...  1055-7903\n1095-9513
# ...                          ...  ...                   ...
# 10470  https://ror.org/02gfc7t72  ...  1175-5334\n1175-5326
# 10471  https://ror.org/0097mvx21  ...  0040-0262\n1996-8175
# 10472  https://ror.org/0215gxf82  ...  1175-5334\n1175-5326
# 10473  https://ror.org/04nfjn472  ...  1055-7903\n1095-9513
# 10474  https://ror.org/01j9p1r26  ...  0181-1584\n1776-100X
#
#                source_host_organization    source_host_organization_name  \
# 0      https://openalex.org/P4310319900  Springer Science+Business Media
# 1      https://openalex.org/P4310321855                        Q15088586
# 2      https://openalex.org/P4310321855                        Q15088586
# 3      https://openalex.org/P4310311648          Oxford University Press
# 4      https://openalex.org/P4310320990                      Elsevier BV
# ...                                 ...                              ...
# 10470  https://openalex.org/P4310321855                        Q15088586
# 10471  https://openalex.org/P4310320595                            Wiley
# 10472  https://openalex.org/P4310321855                        Q15088586
# 10473  https://openalex.org/P4310320990                      Elsevier BV
# 10474                              None                             None
#
#                         source_host_organization_lineage  \
# 0      [https://openalex.org/P4310319965, https://ope...
# 1                     [https://openalex.org/P4310321855]
# 2                     [https://openalex.org/P4310321855]
# 3      [https://openalex.org/P4310311647, https://ope...
# 4                     [https://openalex.org/P4310320990]
# ...                                                  ...
# 10470                 [https://openalex.org/P4310321855]
# 10471                 [https://openalex.org/P4310320595]
# 10472                 [https://openalex.org/P4310321855]
# 10473                 [https://openalex.org/P4310320990]
# 10474                                                 []
#
#                   source_host_organization_lineage_names source_type  is_oa  \
# 0      [Springer Nature, Springer Science+Business Me...     journal   True
# 1                                            [Q15088586]     journal  False
# 2                                            [Q15088586]     journal  False
# 3        [University of Oxford, Oxford University Press]     journal   True
# 4                                          [Elsevier BV]     journal   True
# ...                                                  ...         ...    ...
# 10470                                        [Q15088586]     journal  False
# 10471                                            [Wiley]     journal   True
# 10472                                        [Q15088586]     journal  False
# 10473                                      [Elsevier BV]     journal  False
# 10474                                                 []     journal   True
#
#       oa_status                                             oa_url  \
# 0        hybrid  https://link.springer.com/content/pdf/10.1007/...
# 1        closed                                               None
# 2        closed                                               None
# 3         green  https://research.rug.nl/files/118029670/syz027...
# 4        hybrid        https://doi.org/10.1016/j.ympev.2019.05.013
# ...         ...                                                ...
# 10470    closed                                               None
# 10471    closed  https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 10472    closed                                               None
# 10473    closed                                               None
# 10474    closed  https://zenodo.org/record/7828891/files/source...
#
#       any_repository_has_fulltext
# 0                           False
# 1                           False
# 2                           False
# 3                            True
# 4                           False
# ...                           ...
# 10470                       False
# 10471                       False
# 10472                       False
# 10473                       False
# 10474                        True
#
# [10475 rows x 65 columns]

# %%
only_eu_authors.to_pickle("./data/EU27_authors_with_all_taxonomic_articles.pkl")
single_eu_authors.to_pickle("./data/EU27_authors_taxonomic_articles_no_duplicates.pkl")

# %% [markdown]
# We now have a list of all European authors of taxonomic articles from taxonomic journals.
